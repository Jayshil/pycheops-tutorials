# %% [markdown]
# # MultiVisit Analysis of two transits of WASP-189b
#
# We have analysed two visits of HD106315 individually -- now we will use `pycheops.MultiVisit` to analyse both of the visits simultaneously.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from dace.cheops import Cheops
import pycheops
from uncertainties import ufloat
from uncertainties.umath import sqrt as usqrt
import lmfit as lmf
import re
from pycheops.utils import phaser

# %% [markdown]
# Let's load the saved datasets using `MultiVisit` class.

# %%
M = pycheops.MultiVisit('WASP-189', ident='none')
# Out:
#  N  file_key                   Aperture last_ GP  Glint pipe_ver
#  ---------------------------------------------------------------------------
#   1 CH_PR100036_TG000701_V0200 DEFAULT  emcee Yes Yes   13.1.0
#   2 CH_PR100036_TG000701_V0200 DEFAULT  emcee Yes Yes   13.1.0

# %%
rprs = np.random.normal(0.060907361661750425, 0.003144594526637345, 10000)
dep, dep_err = np.mean((rprs**2)*1e6), np.std((rprs**2)*1e6)

"""
star = pycheops.StarProperties(dd.target)
print(star)
"""
teff = np.random.normal(8000, 80, 10000)
logg = np.random.normal(3.9, 0.2, 10000)
mh = np.random.normal(0.29, 0.13, 10000)
h1, h2 = np.zeros(10000), np.zeros(10000)
cdc = pycheops.ld.stagger_power2_interpolator('CHEOPS')
for i in range(len(teff)):
    c1, c2, h1[i], h2[i] = cdc(teff[i], logg[i], mh[i])
# However, since Teff is out of the range of stagger, the above code will produce Nan in h1 and h2
# So, we are using values of h1 and h2 from tutorial.

# %%
# I have tried this with nroll=3, but it is better with nroll=1 (Delta  BIC = ~200)
TJD_0 = M.tzero(2456706.4558, 2.7240338) # First argument is T_0 in previous epoch
result = M.fit_transit(unroll=True, nroll=1,
                       extra_priors={
                           'T_0':ufloat(TJD_0,0.1),
                            'h_1':ufloat(0.787, 0.100),
                            'logrhoprior':ufloat(-0.89, 0.33)},
                       burn=512, steps=256, nwalkers=256)
# Out:
# Running burn-in ..
# 100%|██████████| 512/512 [04:25<00:00,  1.93it/s]
# Running sampler ..
# 100%|██████████| 256/256 [02:13<00:00,  1.91it/s]

# %%
print(M.fit_report(min_correl=0.8))
# Out:
# [[Fit Statistics]]
#     # fitting method   = emcee
#     # function evals   = 170699
#     # data points      = 1786
#     # variables        = 12
#     chi-square         = 2568.50570
#     reduced chi-square = 1.44786116
#     Akaike info crit   = -27683.0133
#     Bayesian info crit = -27617.1605
#     RMS residual       = 100.7 ppm
# [[Variables]]
#     D:               0.00503016 +/- 2.0315e-05 (0.40%) (init = 0.004969525)
#     W:               0.06622165 +/- 9.5156e-05 (0.14%) (init = 0.06679328)
#     b:               0.45435114 +/- 0.01862835 (4.10%) (init = 0.4125947)
#     P:               2.724034 (fixed)
#     T_0:             2016.43506 +/- 5.0057e-05 (0.00%) (init = 2016.436)
#     f_c:             0 (fixed)
#     f_s:             0 (fixed)
#     h_1:             0.79451755 +/- 0.00264377 (0.33%) (init = 0.7828273)
#     h_2:             0.529 (fixed)
#     k:               0.07092365 == 'sqrt(D)'
#     aR:              4.66139846 == 'sqrt((1+k)**2-b**2)/W/pi'
#     sini:            0.99523837 == 'sqrt(1 - (b/aR)**2)'
#     logrho:         -0.73718960 == 'log10(4.3275e-4*((1+k)**2-b**2)**1.5/W**3/P**2)'
#     e:               0.00000000 == 'f_c**2 + f_s**2'
#     q_1:             0.22184100 == '(1-h_2)**2'
#     q_2:             0.56373152 == '(h_1-h_2)/(1-h_2)'
#     log_sigma_w:    -9.77817752 +/- 0.05273848 (0.54%) (init = -6)
#     c_01:            1.00004087 +/- 5.6682e-06 (0.00%) (init = 1.00004)
#     dfdbg_01:        2.0943e-04 +/- 5.4728e-05 (26.13%) (init = 0.0001584885)
#     glint_scale_01:  1.08597218 +/- 0.12853879 (11.84%) (init = 1.059387)
#     c_02:            1.00003248 +/- 5.0551e-06 (0.00%) (init = 1.000029)
#     dfdsmear_02:     4.8549e-05 +/- 1.9163e-05 (39.47%) (init = 3.992065e-05)
#     glint_scale_02:  1.01261920 +/- 0.12022787 (11.87%) (init = 1.00098)
# [[Correlations]] (unreported correlations are < 0.800)
#     C(D, b) =  0.949
#     C(W, b) =  0.874
# [[Priors]]
#     T_0:            2016.43646 +/- 0.10000000
#     h_1:            0.78700000 +/- 0.10000000
#     logrhoprior:   -0.89000000 +/- 0.33000000
# [[Software versions]]
#     CHEOPS DRP : 13.1.0
#     pycheops   : 0.9.16
#     lmfit      : 1.0.2

# %%
M.plot_fit(binwidth=0.001, data_offset=0.004, res_offset=0.005, detrend=True, figsize=(16,9));

# %% [markdown]
# ## Trend of Roll-Anlge with time

# %%
fig,ax = plt.subplots(figsize=(8,4.5),nrows=2,sharex=True)
t = M.datasets[0].lc['time']
t0 = np.floor(t[0])
roll_angle = M.datasets[0].lc['roll_angle']
ax[0].plot(t-t0,roll_angle,'.')
ax[0].set_ylabel('Roll angle [$^{\circ}$]')
drdt = np.gradient(roll_angle)
Omega = np.nanmedian(drdt)
ax[1].plot(t-t0,drdt/Omega,'.')
ax[1].set_ylim(0.99,1.01)
ax[1].set_xlabel('Time')
ax[1].set_ylabel('$\Omega/<\Omega>$');

# %% [markdown]
# Wow! The variations can be indeed high! We can remove this correlations as follows:
#
#  - We can either ignore it (only if trends are not large)
#  - We can increase nroll (upto which harmonics of roll angle we want to include in decorrelation)
#  - Or we can remove the prior decorrelation first and then fit for it (using `unwrap=True`).

# %%
result = M.fit_transit(unroll=True, nroll=1, unwrap=True,
                       extra_priors={
                           'T_0':ufloat(TJD_0,0.1),
                           'h_1':ufloat(0.787, 0.100),
                           'logrhoprior':ufloat(-0.89, 0.33)},
                           burn=512, steps=256, nwalkers=256)
# Out:
# Running burn-in ..
# 100%|██████████| 512/512 [04:18<00:00,  1.98it/s]
# Running sampler ..
# 100%|██████████| 256/256 [02:09<00:00,  1.98it/s]

# %%
print(M.fit_report(min_correl=0.8))
# Out:
# [[Fit Statistics]]
#     # fitting method   = emcee
#     # function evals   = 170435
#     # data points      = 1786
#     # variables        = 12
#     chi-square         = 3391.15782
#     reduced chi-square = 1.91158840
#     Akaike info crit   = -27797.8139
#     Bayesian info crit = -27731.9610
#     RMS residual       = 110.8 ppm
# [[Variables]]
#     D:               0.00499886 +/- 1.8378e-05 (0.37%) (init = 0.004969525)
#     W:               0.06618433 +/- 8.8414e-05 (0.13%) (init = 0.06679328)
#     b:               0.42912952 +/- 0.01862121 (4.34%) (init = 0.4125947)
#     P:               2.724034 (fixed)
#     T_0:             2016.43508 +/- 4.6812e-05 (0.00%) (init = 2016.436)
#     f_c:             0 (fixed)
#     f_s:             0 (fixed)
#     h_1:             0.79132406 +/- 0.00263520 (0.33%) (init = 0.7828273)
#     h_2:             0.529 (fixed)
#     k:               0.07070261 == 'sqrt(D)'
#     aR:              4.71779818 == 'sqrt((1+k)**2-b**2)/W/pi'
#     sini:            0.99585457 == 'sqrt(1 - (b/aR)**2)'
#     logrho:         -0.72152021 == 'log10(4.3275e-4*((1+k)**2-b**2)**1.5/W**3/P**2)'
#     e:               0.00000000 == 'f_c**2 + f_s**2'
#     q_1:             0.22184100 == '(1-h_2)**2'
#     q_2:             0.55695130 == '(h_1-h_2)/(1-h_2)'
#     log_sigma_w:    -9.90092287 +/- 0.06292988 (0.64%) (init = -6)
#     c_01:            1.00004618 +/- 5.5077e-06 (0.00%) (init = 1.00004)
#     dfdbg_01:        2.1398e-04 +/- 5.2392e-05 (24.48%) (init = 0.0001584885)
#     glint_scale_01:  1.06061230 +/- 0.12369566 (11.66%) (init = 1.059387)
#     c_02:            1.00001347 +/- 4.9389e-06 (0.00%) (init = 1.000029)
#     dfdsmear_02:     4.0062e-05 +/- 1.8845e-05 (47.04%) (init = 3.992065e-05)
#     glint_scale_02:  1.01028486 +/- 0.11336533 (11.22%) (init = 1.00098)
# [[Correlations]] (unreported correlations are < 0.800)
#     C(D, b) =  0.946
#     C(W, b) =  0.853
# [[Priors]]
#     T_0:            2016.43646 +/- 0.10000000
#     h_1:            0.78700000 +/- 0.10000000
#     logrhoprior:   -0.89000000 +/- 0.33000000
# [[Software versions]]
#     CHEOPS DRP : 13.1.0
#     pycheops   : 0.9.16
#     lmfit      : 1.0.2

# %%
M.plot_fit(binwidth=0.001, data_offset=0.004, res_offset=0.005, detrend=True, figsize=(16,9));

# %%
M.corner_plot(plotkeys='all');

# %%
M.trail_plot();

# %%
result.params
# Out:
# Parameters([('D',
#              <Parameter 'D', value=0.004998859119943831 +/- 1.84e-05, bounds=[0.0009292737966486089:0.014893578717578963]>),
#             ('W',
#              <Parameter 'W', value=0.06618432841929306 +/- 8.84e-05, bounds=[0.0166939925635284:0.2671038810164544]>),
#             ('b',
#              <Parameter 'b', value=0.42912951578483094 +/- 0.0186, bounds=[0:1]>),
#             ('P', <Parameter 'P', value=2.7240338 (fixed), bounds=[0:inf]>),
#             ('T_0',
#              <Parameter 'T_0', value=2016.4350840114375 +/- 4.68e-05, bounds=[2016.3445763296606:2016.5265234771366]>),
#             ('f_c', <Parameter 'f_c', value=0.0 (fixed), bounds=[-1:1]>),
#             ('f_s', <Parameter 'f_s', value=0.0 (fixed), bounds=[-1:1]>),
#             ('h_1',
#              <Parameter 'h_1', value=0.7913240625182518 +/- 0.00264, bounds=[0:1]>),
#             ('h_2', <Parameter 'h_2', value=0.529 (fixed), bounds=[0:1]>),
#             ('k',
#              <Parameter 'k', value=0.07070261041817219, bounds=[0:1], expr='sqrt(D)'>),
#             ('aR',
#              <Parameter 'aR', value=4.717798177676513, bounds=[1:inf], expr='sqrt((1+k)**2-b**2)/W/pi'>),
#             ('sini',
#              <Parameter 'sini', value=0.9958545740384919, bounds=[-inf:inf], expr='sqrt(1 - (b/aR)**2)'>),
#             ('logrho',
#              <Parameter 'logrho', value=-0.7215202145398639, bounds=[-9:6], expr='log10(4.3275e-4*((1+k)**2-b**2)**1.5/W**3/P**2)'>),
#             ('e',
#              <Parameter 'e', value=0.0, bounds=[0:1], expr='f_c**2 + f_s**2'>),
#             ('q_1',
#              <Parameter 'q_1', value=0.22184099999999998, bounds=[0:1], expr='(1-h_2)**2'>),
#             ('q_2',
#              <Parameter 'q_2', value=0.5569513004633796, bounds=[0:1], expr='(h_1-h_2)/(1-h_2)'>),
#             ('log_sigma_w',
#              <Parameter 'log_sigma_w', value=-9.900922871843333 +/- 0.0629, bounds=[-12:-2]>),
#             ('c_01',
#              <Parameter 'c_01', value=1.0000461764335862 +/- 5.51e-06, bounds=[0.49714974621829444:2.0005240688373305]>),
#             ('dfdbg_01',
#              <Parameter 'dfdbg_01', value=0.0002139820889280053 +/- 5.24e-05, bounds=[-inf:inf]>),
#             ('glint_scale_01',
#              <Parameter 'glint_scale_01', value=1.0606122954001116 +/- 0.124, bounds=[0:2]>),
#             ('c_02',
#              <Parameter 'c_02', value=1.0000134650289418 +/- 4.94e-06, bounds=[0.4970110427818445:2.000734565507997]>),
#             ('dfdsmear_02',
#              <Parameter 'dfdsmear_02', value=4.006217954854241e-05 +/- 1.88e-05, bounds=[-inf:inf]>),
#             ('glint_scale_02',
#              <Parameter 'glint_scale_02', value=1.0102848579347175 +/- 0.113, bounds=[0:2]>)])
