# %% [markdown]
# # Two step fitting of data using GP: Exponential-Matern Kernel
#
# This approach to fit data to the given data in two step is implemented in Patel & Espinoza (2021). The idea is to use Gaussian Processes to model the "extra" noise (apart from the transit signal) in the data. This method is in contrast to the method generally used in the analysis by `pycheops` which include *decorrelation* of instrumental parameters (because, we know their properties and can well correct for them). While in this approach we won't follow this --- instead we will directly fit GP noise model to the data. There is a caveat to this approach: if not handled properly, it can produce larger uncertainties in the retrieved planetary parameters (GP can try to fit transit signal as noise). So, what we will do is to fit only out-of-transit data points first (and thus excluding the transit signal). Next we can fit the whole dataset (or just the transit signal) with full model (transit model + GP model) with priors on GP hyperparameters as the posteriors found in the first step.
#
# We will use `juliet` to perform all of these tasks: the main reason for this is that, while `pycheops` can perform GP fitting, it doesn't include versatile GP kernels like Exponential-Matern kernel or Quasi-Periodic kernel. The kernel provided by `pycheops` is SHOTerm which is a simple harmonic oscillator kernel and not as versatile as Exp-Matern kernel or QP kernel. However, we still use `pycheops` to extract the transit lightcurve data.
#
# In the present notebook we will use Exponential-Matern kernel to demonstrate the fitting.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from dace.cheops import Cheops
import pycheops
from uncertainties import ufloat
from uncertainties.umath import sqrt as usqrt
import lmfit as lmf
import re
from pycheops.utils import phaser
import matplotlib.gridspec as gd
import juliet as jl
# Out:
# /home/jayshil/anaconda3/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py:20: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   int_types = {_np.int, _np.int8, _np.int16, _np.int32, _np.int64, _np.integer}

# %% [markdown]
# ## Downloading the data
#
# As mentioned, we are going to use `pycheops` to download the data and extracting time, flux and uncertainties in flux from the data.

# %%
# Downloading data
dd = pycheops.Dataset('CH_PR100036_TG000701_V0200')
tim, fl, fle = dd.get_lightcurve(aperture='DEFAULT', decontaminate=True)#, reject_highpoints=True)

# To clip outliers (I would, in general, not prefer using this)
tim, fl, fle = dd.clip_outliers(verbose=True);

# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Transit lightcurve for WASP-189b (Aperture: DEFAULT)')
plt.grid()
# Out:
# Found archive tgzfile /home/jayshil/.local/share/pycheops/CH_PR100036_TG000701_V0200.tgz
#  PI name     : Brice-Olivier DEMORY
#  OBS ID      : 1145201
#  Target      : WASP-189
#  Coordinates : 15:02:44.87 -03:01:53.0
#  Spec. type  : A6V
#  G magnitude : 6.55 +- 0.00
# Light curve data loaded from  /home/jayshil/.local/share/pycheops/CH_PR100036_TG000701_V0200-DEFAULT.fits
# Time stored relative to BJD = 2459016
# Aperture radius used = 25 arcsec
# UTC start:  2020-06-15T18:07:40
# UTC end:    2020-06-18T21:07:01
# Visit duration: 269961 s
# Exposure time: 7 x 4.8 s
# Number of non-flagged data points: 4758
# Efficiency (non-flagged data): 59.2 %
# Light curve corrected for flux from background stars
# Mean counts = 140556171.2
# Median counts = 140629390.3
# RMS counts = 222219.7 [1580 ppm]
# Median standard error = 11901.2 [85 ppm]
# Median background = 262452 e-/pxl
# Mean contamination = 733.0 ppm
# Mean smearing correction = 60.4 ppm
#
# Rejected 12 points more than 5.0 x MAD = 356 ppm from the median

# %% [markdown]
# ### Planetary and Stellar Properties
#
# Let's now extract planetary and stellar properties from online database (this would be helpful in determining priors on fit).

# %%
# Using ExoCTK to get planetary properties
rprs = np.random.normal(0.060907361661750425, 0.003144594526637345, 10000)
dep, dep_err = np.mean((rprs**2)*1e6), np.std((rprs**2)*1e6)

"""
star = pycheops.StarProperties(dd.target)
print(star)
"""
teff = np.random.normal(8000, 80, 10000)
logg = np.random.normal(3.9, 0.2, 10000)
mh = np.random.normal(0.29, 0.13, 10000)
h1, h2 = np.zeros(10000), np.zeros(10000)
cdc = pycheops.ld.stagger_power2_interpolator('CHEOPS')
for i in range(len(teff)):
    c1, c2, h1[i], h2[i] = cdc(teff[i], logg[i], mh[i])

# %% [markdown]
# ## Renormalising the lightcurve
#
# Note that the out-of-transit points are not at unity --- we will thus perform renormalisation.

# %%
# This code is taken from the pycheops example notebook
P = 2.7240338
BJD_0 = 2456706.4558
cycle = round((dd.bjd_ref-BJD_0)/P)
T_0 = BJD_0 - dd.bjd_ref + (cycle+0)*P
T_1 = BJD_0 - dd.bjd_ref + (cycle+1)*P
T_ec = T_0 + (P/2)

D = dep/1e6  # Depth stored in ppm
W = 0.1819/P    # Width stored in days

try:
    f_c = 0.#np.sqrt(0.093)*np.sin(67.0*np.pi/180)
    f_s = 0.#np.sqrt(0.093)*np.cos(67.0*np.pi/180)
except:
    # From Pepper et al., 2017
    ecosw = 0.#ufloat(-0.004,0.05099)
    esinw = 0.#ufloat(0.031,0.055)
    ecc = usqrt(ecosw**2+esinw**2)
    f_s = 0.#esinw/usqrt(ecc)  # f_s = sqrt(e)sin(omega) = e.sin(omega)/sqrt(e)
    f_c = 0.#ecosw/usqrt(ecc)  # f_c = sqrt(e)cos(omega) = e.cos(omega)/sqrt(e)


# Let's take data from first transit only
mask1 = tim < T_0+(W*P/2)
mask2 = tim > T_1-(W*P/2)
mask = mask1 + mask2

tim, fl, fle = dd.mask_data(mask)
# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.axvline(T_ec, c='k')
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Eclipse lightcurve for WASP-189b (Aperture: OPTIMAL)')
plt.grid()
# Out:
# Masked 791 points

# %%
tim, fl, fle = dd.flatten(T_0, P*W)
# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.axvline(T_ec, c='k')
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Eclipse lightcurve for WASP-189b (Aperture: OPTIMAL)')
plt.grid()

# %%
# Data dictionary for out of transit
tim_oot, fl_oot, fle_oot = {}, {}, {}
mask = np.where(tim > (T_ec + (W*P/2)))[0]
mask = np.hstack((np.where(tim < (T_ec - (W*P/2)))[0], mask))
tim_oot['CHEOPS'], fl_oot['CHEOPS'], fle_oot['CHEOPS'] = tim[mask], fl[mask], fle[mask]

# Data dictionary for full dataset
tim_full, fl_full, fle_full = {}, {}, {}
tim_full['CHEOPS'], fl_full['CHEOPS'], fle_full['CHEOPS'] = tim, fl, fle

# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered', label='All points')
plt.errorbar(tim[mask], fl[mask], yerr=fle[mask], fmt='.', c='cornflowerblue', alpha=0.5, label='Out-of-transit points')
plt.axvline(x=T_ec, c='k', lw=3)
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)', fontsize=16)
plt.ylabel('Normalised Flux', fontsize=16)
plt.title('Eclipse lightcurve for WASP-189b (Aperture: DEFAULT)', fontsize=18)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %% [markdown]
# ## Fitting Out-of-transit lightcurve
#
# First we fit a GP model along with instrumental parameters to the out-of-transit parameters.

# %%
# Instrumental parameters
params_ins = ['mdilution_CHEOPS', 'mflux_CHEOPS', 'sigma_w_CHEOPS']
dist_ins = ['fixed', 'normal', 'loguniform']
hyper_ins = [1., [0., 0.1], [0.1, 10000.]]

# GP Params
params_gp = ['GP_B_CHEOPS', 'GP_C_CHEOPS', 'GP_L_CHEOPS', 'GP_Prot_CHEOPS']
dist_gp = ['loguniform', 'loguniform', 'loguniform','loguniform']
hyper_gp = [[1e-5,1e3], [1e-5,1e4], [1e-3, 1e3], [1.,1e2]]

## Performing GP fit
params_gp_only = params_ins + params_gp
dist_gp_only = dist_ins + dist_gp
hyper_gp_only = hyper_ins + hyper_gp

### Populating prior dict
priors = {}
for i, j, k in zip(params_gp_only, dist_gp_only, hyper_gp_only):
    priors[i] = {}
    priors[i]['distribution'], priors[i]['hyperparameters'] = j, k

## Running GP only fit
data = jl.load(priors=priors, t_lc=tim_oot, y_lc=fl_oot, yerr_lc=fle_oot, GP_regressors_lc=tim_oot, out_folder='juliet/juliet_oot_exp')
res_gp_only = data.fit(n_live_points = 500, verbose = True)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  500
#  dimensionality =    6
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.992780
# Replacements:                                550
# Total Samples:                               554
# Nested Sampling ln(Z):              -4885.379842
# Importance Nested Sampling ln(Z):   27247.907234 +/-  0.999094
# Acceptance Rate:                        0.980392
# Replacements:                                600
# Total Samples:                               612
# Nested Sampling ln(Z):                167.914357
# Importance Nested Sampling ln(Z):   27247.807666 +/-  0.999180
# Acceptance Rate:                        0.968703
# Replacements:                                650
# Total Samples:                               671
# Nested Sampling ln(Z):               3663.963545
# Importance Nested Sampling ln(Z):   27259.178355 +/-  0.999244
# Acceptance Rate:                        0.949796
# Replacements:                                700
# Total Samples:                               737
# Nested Sampling ln(Z):               6005.726076
# Importance Nested Sampling ln(Z):   27259.085687 +/-  0.998161
# Acceptance Rate:                        0.916870
# Replacements:                                750
# Total Samples:                               818
# Nested Sampling ln(Z):               8571.366390
# Importance Nested Sampling ln(Z):   27258.981412 +/-  0.998229
# Acceptance Rate:                        0.893855
# Replacements:                                800
# Total Samples:                               895
# Nested Sampling ln(Z):              10425.148882
# Importance Nested Sampling ln(Z):   27258.682758 +/-  0.998281
# Acceptance Rate:                        0.872690
# Replacements:                                850
# Total Samples:                               974
# Nested Sampling ln(Z):              12041.268005
# Importance Nested Sampling ln(Z):   27258.412467 +/-  0.998297
# Acceptance Rate:                        0.860421
# Replacements:                                900
# Total Samples:                              1046
# Nested Sampling ln(Z):              13044.819132
# Importance Nested Sampling ln(Z):   27258.196001 +/-  0.998324
# Acceptance Rate:                        0.854317
# Replacements:                                950
# Total Samples:                              1112
# Nested Sampling ln(Z):              14121.490126
# Importance Nested Sampling ln(Z):   27258.031289 +/-  0.998353
# Acceptance Rate:                        0.840336
# Replacements:                               1000
# Total Samples:                              1190
# Nested Sampling ln(Z):              15241.796275
# Importance Nested Sampling ln(Z):   27257.840545 +/-  0.998382
# Acceptance Rate:                        0.828729
# Replacements:                               1050
# Total Samples:                              1267
# Nested Sampling ln(Z):              16102.844332
# Importance Nested Sampling ln(Z):   27257.667850 +/-  0.998408
# Acceptance Rate:                        0.820283
# Replacements:                               1100
# Total Samples:                              1341
# Nested Sampling ln(Z):              16980.549010
# Importance Nested Sampling ln(Z):   27257.502893 +/-  0.998429
# Acceptance Rate:                        0.803634
# Replacements:                               1150
# Total Samples:                              1431
# Nested Sampling ln(Z):              18183.144323
# Importance Nested Sampling ln(Z):   27257.318712 +/-  0.998453
# Acceptance Rate:                        0.796284
# Replacements:                               1200
# Total Samples:                              1507
# Nested Sampling ln(Z):              19091.242014
# Importance Nested Sampling ln(Z):   27257.178167 +/-  0.998459
# Acceptance Rate:                        0.784191
# Replacements:                               1250
# Total Samples:                              1594
# Nested Sampling ln(Z):              20024.937352
# Importance Nested Sampling ln(Z):   27257.015544 +/-  0.998478
# Acceptance Rate:                        0.781250
# Replacements:                               1300
# Total Samples:                              1664
# Nested Sampling ln(Z):              20958.369786
# Importance Nested Sampling ln(Z):   27256.891969 +/-  0.998442
# Acceptance Rate:                        0.779446
# Replacements:                               1350
# Total Samples:                              1732
# Nested Sampling ln(Z):              21838.825997
# Importance Nested Sampling ln(Z):   27256.775731 +/-  0.998454
# Acceptance Rate:                        0.769654
# Replacements:                               1400
# Total Samples:                              1819
# Nested Sampling ln(Z):              22621.741070
# Importance Nested Sampling ln(Z):   27256.625401 +/-  0.998467
# Acceptance Rate:                        0.766385
# Replacements:                               1450
# Total Samples:                              1892
# Nested Sampling ln(Z):              23305.038424
# Importance Nested Sampling ln(Z):   27256.513271 +/-  0.998476
# Acceptance Rate:                        0.764137
# Replacements:                               1500
# Total Samples:                              1963
# Nested Sampling ln(Z):              23898.857129
# Importance Nested Sampling ln(Z):   27256.397792 +/-  0.995582
# Acceptance Rate:                        0.757946
# Replacements:                               1550
# Total Samples:                              2045
# Nested Sampling ln(Z):              24574.505478
# Importance Nested Sampling ln(Z):   27256.279340 +/-  0.995557
# Acceptance Rate:                        0.755073
# Replacements:                               1600
# Total Samples:                              2119
# Nested Sampling ln(Z):              25052.568270
# Importance Nested Sampling ln(Z):   27256.181367 +/-  0.994182
# Acceptance Rate:                        0.747283
# Replacements:                               1650
# Total Samples:                              2208
# Nested Sampling ln(Z):              25327.113843
# Importance Nested Sampling ln(Z):   27256.056422 +/-  0.994171
# Acceptance Rate:                        0.741064
# Replacements:                               1700
# Total Samples:                              2294
# Nested Sampling ln(Z):              25763.381789
# Importance Nested Sampling ln(Z):   27256.002934 +/-  0.935145
# Acceptance Rate:                        0.736222
# Replacements:                               1750
# Total Samples:                              2377
# Nested Sampling ln(Z):              26096.635780
# Importance Nested Sampling ln(Z):   27256.358653 +/-  0.692820
# Acceptance Rate:                        0.732601
# Replacements:                               1800
# Total Samples:                              2457
# Nested Sampling ln(Z):              26288.873205
# Importance Nested Sampling ln(Z):   27256.239272 +/-  0.692837
# Acceptance Rate:                        0.730648
# Replacements:                               1850
# Total Samples:                              2532
# Nested Sampling ln(Z):              26439.311637
# Importance Nested Sampling ln(Z):   27269.766578 +/-  0.999801
# Acceptance Rate:                        0.724085
# Replacements:                               1900
# Total Samples:                              2624
# Nested Sampling ln(Z):              26575.383302
# Importance Nested Sampling ln(Z):   27269.636517 +/-  0.999648
# Acceptance Rate:                        0.720621
# Replacements:                               1950
# Total Samples:                              2706
# Nested Sampling ln(Z):              26667.549472
# Importance Nested Sampling ln(Z):   27269.537227 +/-  0.999653
# Acceptance Rate:                        0.713776
# Replacements:                               2000
# Total Samples:                              2802
# Nested Sampling ln(Z):              26764.829783
# Importance Nested Sampling ln(Z):   27269.415749 +/-  0.999660
# Acceptance Rate:                        0.705923
# Replacements:                               2050
# Total Samples:                              2904
# Nested Sampling ln(Z):              26837.035573
# Importance Nested Sampling ln(Z):   27269.310713 +/-  0.981905
# Acceptance Rate:                        0.701169
# Replacements:                               2100
# Total Samples:                              2995
# Nested Sampling ln(Z):              26901.319228
# Importance Nested Sampling ln(Z):   27269.196745 +/-  0.979702
# Acceptance Rate:                        0.695568
# Replacements:                               2150
# Total Samples:                              3091
# Nested Sampling ln(Z):              26950.324875
# Importance Nested Sampling ln(Z):   27269.092164 +/-  0.979706
# Acceptance Rate:                        0.693350
# Replacements:                               2200
# Total Samples:                              3173
# Nested Sampling ln(Z):              26990.310621
# Importance Nested Sampling ln(Z):   27269.300008 +/-  0.768995
# Acceptance Rate:                        0.690396
# Replacements:                               2250
# Total Samples:                              3259
# Nested Sampling ln(Z):              27027.647900
# Importance Nested Sampling ln(Z):   27269.208873 +/-  0.769001
# Acceptance Rate:                        0.687388
# Replacements:                               2300
# Total Samples:                              3346
# Nested Sampling ln(Z):              27058.803771
# Importance Nested Sampling ln(Z):   27269.123197 +/-  0.769001
# Acceptance Rate:                        0.683935
# Replacements:                               2350
# Total Samples:                              3436
# Nested Sampling ln(Z):              27084.231330
# Importance Nested Sampling ln(Z):   27269.035386 +/-  0.768889
# Acceptance Rate:                        0.680851
# Replacements:                               2400
# Total Samples:                              3525
# Nested Sampling ln(Z):              27107.655572
# Importance Nested Sampling ln(Z):   27268.923387 +/-  0.768718
# Acceptance Rate:                        0.675303
# Replacements:                               2450
# Total Samples:                              3628
# Nested Sampling ln(Z):              27133.584117
# Importance Nested Sampling ln(Z):   27268.796853 +/-  0.768500
# Acceptance Rate:                        0.674400
# Replacements:                               2500
# Total Samples:                              3707
# Nested Sampling ln(Z):              27146.408282
# Importance Nested Sampling ln(Z):   27272.489208 +/-  0.977626
# Acceptance Rate:                        0.670700
# Replacements:                               2550
# Total Samples:                              3802
# Nested Sampling ln(Z):              27158.336354
# Importance Nested Sampling ln(Z):   27272.376268 +/-  0.977625
# Acceptance Rate:                        0.663435
# Replacements:                               2600
# Total Samples:                              3919
# Nested Sampling ln(Z):              27170.544285
# Importance Nested Sampling ln(Z):   27272.298360 +/-  0.942155
# Acceptance Rate:                        0.656916
# Replacements:                               2650
# Total Samples:                              4034
# Nested Sampling ln(Z):              27178.852927
# Importance Nested Sampling ln(Z):   27272.186788 +/-  0.941923
# Acceptance Rate:                        0.654070
# Replacements:                               2700
# Total Samples:                              4128
# Nested Sampling ln(Z):              27188.619312
# Importance Nested Sampling ln(Z):   27272.125503 +/-  0.905327
# Acceptance Rate:                        0.649504
# Replacements:                               2750
# Total Samples:                              4234
# Nested Sampling ln(Z):              27194.381037
# Importance Nested Sampling ln(Z):   27272.007833 +/-  0.905305
# Acceptance Rate:                        0.646353
# Replacements:                               2800
# Total Samples:                              4332
# Nested Sampling ln(Z):              27201.187909
# Importance Nested Sampling ln(Z):   27271.906615 +/-  0.905297
# Acceptance Rate:                        0.639013
# Replacements:                               2850
# Total Samples:                              4460
# Nested Sampling ln(Z):              27206.669393
# Importance Nested Sampling ln(Z):   27271.792792 +/-  0.905291
# Acceptance Rate:                        0.637643
# Replacements:                               2900
# Total Samples:                              4548
# Nested Sampling ln(Z):              27213.062904
# Importance Nested Sampling ln(Z):   27271.712774 +/-  0.905036
# Acceptance Rate:                        0.635228
# Replacements:                               2950
# Total Samples:                              4644
# Nested Sampling ln(Z):              27217.385172
# Importance Nested Sampling ln(Z):   27271.611264 +/-  0.901023
# Acceptance Rate:                        0.632378
# Replacements:                               3000
# Total Samples:                              4744
# Nested Sampling ln(Z):              27222.073158
# Importance Nested Sampling ln(Z):   27271.510262 +/-  0.901002
# Acceptance Rate:                        0.629255
# Replacements:                               3050
# Total Samples:                              4847
# Nested Sampling ln(Z):              27225.956561
# Importance Nested Sampling ln(Z):   27271.417160 +/-  0.900625
# Acceptance Rate:                        0.625883
# Replacements:                               3100
# Total Samples:                              4953
# Nested Sampling ln(Z):              27228.480131
# Importance Nested Sampling ln(Z):   27271.321531 +/-  0.900602
# Acceptance Rate:                        0.625000
# Replacements:                               3150
# Total Samples:                              5040
# Nested Sampling ln(Z):              27231.005851
# Importance Nested Sampling ln(Z):   27271.242611 +/-  0.896661
# Acceptance Rate:                        0.622568
# Replacements:                               3200
# Total Samples:                              5140
# Nested Sampling ln(Z):              27233.495036
# Importance Nested Sampling ln(Z):   27271.151830 +/-  0.893793
# Acceptance Rate:                        0.621177
# Replacements:                               3250
# Total Samples:                              5232
# Nested Sampling ln(Z):              27235.699796
# Importance Nested Sampling ln(Z):   27271.267226 +/-  0.751786
# Acceptance Rate:                        0.616822
# Replacements:                               3300
# Total Samples:                              5350
# Nested Sampling ln(Z):              27237.504800
# Importance Nested Sampling ln(Z):   27271.161226 +/-  0.750790
# Acceptance Rate:                        0.612655
# Replacements:                               3350
# Total Samples:                              5468
# Nested Sampling ln(Z):              27239.356957
# Importance Nested Sampling ln(Z):   27271.193444 +/-  0.652541
# Acceptance Rate:                        0.610632
# Replacements:                               3400
# Total Samples:                              5568
# Nested Sampling ln(Z):              27240.805342
# Importance Nested Sampling ln(Z):   27271.149776 +/-  0.613570
# Acceptance Rate:                        0.606753
# Replacements:                               3450
# Total Samples:                              5686
# Nested Sampling ln(Z):              27242.372385
# Importance Nested Sampling ln(Z):   27271.044564 +/-  0.603859
# Acceptance Rate:                        0.601271
# Replacements:                               3500
# Total Samples:                              5821
# Nested Sampling ln(Z):              27243.862139
# Importance Nested Sampling ln(Z):   27271.348021 +/-  0.469890
# Acceptance Rate:                        0.597643
# Replacements:                               3550
# Total Samples:                              5940
# Nested Sampling ln(Z):              27245.149739
# Importance Nested Sampling ln(Z):   27271.419414 +/-  0.421164
# Acceptance Rate:                        0.596718
# Replacements:                               3600
# Total Samples:                              6033
# Nested Sampling ln(Z):              27246.249889
# Importance Nested Sampling ln(Z):   27271.422675 +/-  0.393811
# Acceptance Rate:                        0.594559
# Replacements:                               3650
# Total Samples:                              6139
# Nested Sampling ln(Z):              27247.290639
# Importance Nested Sampling ln(Z):   27271.379733 +/-  0.375047
# Acceptance Rate:                        0.592854
# Replacements:                               3700
# Total Samples:                              6241
# Nested Sampling ln(Z):              27248.105452
# Importance Nested Sampling ln(Z):   27271.279536 +/-  0.372368
# Acceptance Rate:                        0.589530
# Replacements:                               3750
# Total Samples:                              6361
# Nested Sampling ln(Z):              27248.896701
# Importance Nested Sampling ln(Z):   27271.170259 +/-  0.370549
# Acceptance Rate:                        0.586691
# Replacements:                               3800
# Total Samples:                              6477
# Nested Sampling ln(Z):              27249.619175
# Importance Nested Sampling ln(Z):   27271.082049 +/-  0.366283
# Acceptance Rate:                        0.583068
# Replacements:                               3850
# Total Samples:                              6603
# Nested Sampling ln(Z):              27250.254930
# Importance Nested Sampling ln(Z):   27270.991592 +/-  0.357733
# Acceptance Rate:                        0.580184
# Replacements:                               3900
# Total Samples:                              6722
# Nested Sampling ln(Z):              27250.880633
# Importance Nested Sampling ln(Z):   27270.906181 +/-  0.351102
# Acceptance Rate:                        0.580541
# Replacements:                               3950
# Total Samples:                              6804
# Nested Sampling ln(Z):              27251.435856
# Importance Nested Sampling ln(Z):   27271.010668 +/-  0.307194
# Acceptance Rate:                        0.578955
# Replacements:                               4000
# Total Samples:                              6909
# Nested Sampling ln(Z):              27251.971718
# Importance Nested Sampling ln(Z):   27271.276743 +/-  0.351262
# Acceptance Rate:                        0.577005
# Replacements:                               4050
# Total Samples:                              7019
# Nested Sampling ln(Z):              27252.478743
# Importance Nested Sampling ln(Z):   27271.477732 +/-  0.358208
# Acceptance Rate:                        0.574552
# Replacements:                               4100
# Total Samples:                              7136
# Nested Sampling ln(Z):              27252.958650
# Importance Nested Sampling ln(Z):   27271.389670 +/-  0.355386
# Acceptance Rate:                        0.570839
# Replacements:                               4150
# Total Samples:                              7270
# Nested Sampling ln(Z):              27253.435830
# Importance Nested Sampling ln(Z):   27271.726538 +/-  0.377245
# Acceptance Rate:                        0.568566
# Replacements:                               4200
# Total Samples:                              7387
# Nested Sampling ln(Z):              27253.994591
# Importance Nested Sampling ln(Z):   27271.664605 +/-  0.366940
# Acceptance Rate:                        0.566214
# Replacements:                               4250
# Total Samples:                              7506
# Nested Sampling ln(Z):              27254.720060
# Importance Nested Sampling ln(Z):   27271.845590 +/-  0.302995
# Acceptance Rate:                        0.564008
# Replacements:                               4300
# Total Samples:                              7624
# Nested Sampling ln(Z):              27255.540734
# Importance Nested Sampling ln(Z):   27271.947531 +/-  0.294182
# Acceptance Rate:                        0.562524
# Replacements:                               4350
# Total Samples:                              7733
# Nested Sampling ln(Z):              27256.393577
# Importance Nested Sampling ln(Z):   27271.949575 +/-  0.276667
# Acceptance Rate:                        0.559298
# Replacements:                               4400
# Total Samples:                              7867
# Nested Sampling ln(Z):              27257.300762
# Importance Nested Sampling ln(Z):   27271.909472 +/-  0.258530
# Acceptance Rate:                        0.557155
# Replacements:                               4450
# Total Samples:                              7987
# Nested Sampling ln(Z):              27258.160428
# Importance Nested Sampling ln(Z):   27271.934601 +/-  0.235270
# Acceptance Rate:                        0.555213
# Replacements:                               4500
# Total Samples:                              8105
# Nested Sampling ln(Z):              27259.000731
# Importance Nested Sampling ln(Z):   27271.880210 +/-  0.226153
# Acceptance Rate:                        0.552587
# Replacements:                               4550
# Total Samples:                              8234
# Nested Sampling ln(Z):              27259.930371
# Importance Nested Sampling ln(Z):   27271.879168 +/-  0.208713
# Acceptance Rate:                        0.550437
# Replacements:                               4600
# Total Samples:                              8357
# Nested Sampling ln(Z):              27260.774749
# Importance Nested Sampling ln(Z):   27271.982730 +/-  0.179775
# Acceptance Rate:                        0.548737
# Replacements:                               4650
# Total Samples:                              8474
# Nested Sampling ln(Z):              27261.544442
# Importance Nested Sampling ln(Z):   27272.049640 +/-  0.168307
# Acceptance Rate:                        0.547275
# Replacements:                               4700
# Total Samples:                              8588
# Nested Sampling ln(Z):              27262.217519
# Importance Nested Sampling ln(Z):   27272.045020 +/-  0.159269
# Acceptance Rate:                        0.546165
# Replacements:                               4750
# Total Samples:                              8697
# Nested Sampling ln(Z):              27262.870955
# Importance Nested Sampling ln(Z):   27272.022166 +/-  0.150407
# Acceptance Rate:                        0.543540
# Replacements:                               4800
# Total Samples:                              8831
# Nested Sampling ln(Z):              27263.518033
# Importance Nested Sampling ln(Z):   27271.992630 +/-  0.142752
# Acceptance Rate:                        0.541113
# Replacements:                               4850
# Total Samples:                              8963
# Nested Sampling ln(Z):              27264.118754
# Importance Nested Sampling ln(Z):   27271.937640 +/-  0.137531
# Acceptance Rate:                        0.538107
# Replacements:                               4900
# Total Samples:                              9106
# Nested Sampling ln(Z):              27264.698550
# Importance Nested Sampling ln(Z):   27271.875186 +/-  0.131616
# Acceptance Rate:                        0.536062
# Replacements:                               4950
# Total Samples:                              9234
# Nested Sampling ln(Z):              27265.215005
# Importance Nested Sampling ln(Z):   27271.867041 +/-  0.124555
# Acceptance Rate:                        0.533846
# Replacements:                               5000
# Total Samples:                              9366
# Nested Sampling ln(Z):              27265.696990
# Importance Nested Sampling ln(Z):   27271.844956 +/-  0.117161
# Acceptance Rate:                        0.530741
# Replacements:                               5050
# Total Samples:                              9515
# Nested Sampling ln(Z):              27266.124965
# Importance Nested Sampling ln(Z):   27271.827275 +/-  0.109123
# Acceptance Rate:                        0.527350
# Replacements:                               5100
# Total Samples:                              9671
# Nested Sampling ln(Z):              27266.546365
# Importance Nested Sampling ln(Z):   27271.833781 +/-  0.110124
# Acceptance Rate:                        0.522048
# Replacements:                               5150
# Total Samples:                              9865
# Nested Sampling ln(Z):              27266.950330
# Importance Nested Sampling ln(Z):   27271.787167 +/-  0.105347
# Acceptance Rate:                        0.515668
# Replacements:                               5200
# Total Samples:                             10084
# Nested Sampling ln(Z):              27267.316702
# Importance Nested Sampling ln(Z):   27271.787321 +/-  0.096355
# Acceptance Rate:                        0.514101
# Replacements:                               5250
# Total Samples:                             10212
# Nested Sampling ln(Z):              27267.650676
# Importance Nested Sampling ln(Z):   27271.813770 +/-  0.091192
# Acceptance Rate:                        0.512226
# Replacements:                               5300
# Total Samples:                             10347
# Nested Sampling ln(Z):              27267.980675
# Importance Nested Sampling ln(Z):   27271.808839 +/-  0.086212
# Acceptance Rate:                        0.511033
# Replacements:                               5350
# Total Samples:                             10469
# Nested Sampling ln(Z):              27268.288118
# Importance Nested Sampling ln(Z):   27271.856726 +/-  0.082102
# Acceptance Rate:                        0.508714
# Replacements:                               5400
# Total Samples:                             10615
# Nested Sampling ln(Z):              27268.582115
# Importance Nested Sampling ln(Z):   27271.889850 +/-  0.080035
# Acceptance Rate:                        0.507402
# Replacements:                               5450
# Total Samples:                             10741
# Nested Sampling ln(Z):              27268.853464
# Importance Nested Sampling ln(Z):   27271.871098 +/-  0.076040
# Acceptance Rate:                        0.505933
# Replacements:                               5500
# Total Samples:                             10871
# Nested Sampling ln(Z):              27269.097800
# Importance Nested Sampling ln(Z):   27271.921400 +/-  0.073711
# Acceptance Rate:                        0.504225
# Replacements:                               5550
# Total Samples:                             11007
# Nested Sampling ln(Z):              27269.314945
# Importance Nested Sampling ln(Z):   27271.921889 +/-  0.070257
# Acceptance Rate:                        0.503960
# Replacements:                               5600
# Total Samples:                             11112
# Nested Sampling ln(Z):              27269.521660
# Importance Nested Sampling ln(Z):   27271.939636 +/-  0.066879
# Acceptance Rate:                        0.502312
# Replacements:                               5650
# Total Samples:                             11248
# Nested Sampling ln(Z):              27269.718329
# Importance Nested Sampling ln(Z):   27271.962398 +/-  0.062933
# Acceptance Rate:                        0.501496
# Replacements:                               5700
# Total Samples:                             11366
# Nested Sampling ln(Z):              27269.910501
# Importance Nested Sampling ln(Z):   27271.971802 +/-  0.059211
# Acceptance Rate:                        0.501614
# Replacements:                               5750
# Total Samples:                             11463
# Nested Sampling ln(Z):              27270.090679
# Importance Nested Sampling ln(Z):   27271.996706 +/-  0.056722
# Acceptance Rate:                        0.500216
# Replacements:                               5800
# Total Samples:                             11595
# Nested Sampling ln(Z):              27270.260302
# Importance Nested Sampling ln(Z):   27271.989442 +/-  0.053535
# Acceptance Rate:                        0.499317
# Replacements:                               5850
# Total Samples:                             11716
# Nested Sampling ln(Z):              27270.424548
# Importance Nested Sampling ln(Z):   27271.980390 +/-  0.051021
# Acceptance Rate:                        0.498563
# Replacements:                               5900
# Total Samples:                             11834
# Nested Sampling ln(Z):              27270.587489
# Importance Nested Sampling ln(Z):   27271.994435 +/-  0.049618
# Acceptance Rate:                        0.497450
# Replacements:                               5950
# Total Samples:                             11961
# Nested Sampling ln(Z):              27270.741968
# Importance Nested Sampling ln(Z):   27271.989088 +/-  0.047272
# Acceptance Rate:                        0.494886
# Replacements:                               6000
# Total Samples:                             12124
# Nested Sampling ln(Z):              27270.885128
# Importance Nested Sampling ln(Z):   27271.976212 +/-  0.045046
# Acceptance Rate:                        0.493113
# Replacements:                               6050
# Total Samples:                             12269
# Nested Sampling ln(Z):              27271.018420
# Importance Nested Sampling ln(Z):   27272.009989 +/-  0.043077
# Acceptance Rate:                        0.492571
# Replacements:                               6100
# Total Samples:                             12384
# Nested Sampling ln(Z):              27271.144406
# Importance Nested Sampling ln(Z):   27272.001528 +/-  0.041363
# Acceptance Rate:                        0.492394
# Replacements:                               6150
# Total Samples:                             12490
# Nested Sampling ln(Z):              27271.263677
# Importance Nested Sampling ln(Z):   27272.004909 +/-  0.039729
# Acceptance Rate:                        0.491245
# Replacements:                               6200
# Total Samples:                             12621
# Nested Sampling ln(Z):              27271.372938
# Importance Nested Sampling ln(Z):   27271.994723 +/-  0.038275
# Acceptance Rate:                        0.490542
# Replacements:                               6250
# Total Samples:                             12741
# Nested Sampling ln(Z):              27271.475715
# Importance Nested Sampling ln(Z):   27271.998111 +/-  0.036884
# Acceptance Rate:                        0.489472
# Replacements:                               6300
# Total Samples:                             12871
# Nested Sampling ln(Z):              27271.572735
# Importance Nested Sampling ln(Z):   27272.004975 +/-  0.035512
# Acceptance Rate:                        0.487674
# Replacements:                               6350
# Total Samples:                             13021
# Nested Sampling ln(Z):              27271.662491
# Importance Nested Sampling ln(Z):   27271.996491 +/-  0.034204
# Acceptance Rate:                        0.486248
# Replacements:                               6400
# Total Samples:                             13162
# Nested Sampling ln(Z):              27271.748205
# Importance Nested Sampling ln(Z):   27272.005474 +/-  0.032896
# Acceptance Rate:                        0.485656
# Replacements:                               6450
# Total Samples:                             13281
# Nested Sampling ln(Z):              27271.829430
# Importance Nested Sampling ln(Z):   27272.013939 +/-  0.031865
# Acceptance Rate:                        0.485111
# Replacements:                               6500
# Total Samples:                             13399
# Nested Sampling ln(Z):              27271.906093
# Importance Nested Sampling ln(Z):   27272.011472 +/-  0.031032
# Acceptance Rate:                        0.483395
# Replacements:                               6550
# Total Samples:                             13550
# Nested Sampling ln(Z):              27271.978959
# Importance Nested Sampling ln(Z):   27271.995079 +/-  0.029951
# Acceptance Rate:                        0.482174
# Replacements:                               6600
# Total Samples:                             13688
# Nested Sampling ln(Z):              27272.046222
# Importance Nested Sampling ln(Z):   27271.983507 +/-  0.029020
# Acceptance Rate:                        0.481326
# Replacements:                               6650
# Total Samples:                             13816
# Nested Sampling ln(Z):              27272.108401
# Importance Nested Sampling ln(Z):   27271.974733 +/-  0.028243
# Acceptance Rate:                        0.479633
# Replacements:                               6700
# Total Samples:                             13969
# Nested Sampling ln(Z):              27272.166559
# Importance Nested Sampling ln(Z):   27271.971597 +/-  0.027482
# Acceptance Rate:                        0.477538
# Replacements:                               6750
# Total Samples:                             14135
# Nested Sampling ln(Z):              27272.220877
# Importance Nested Sampling ln(Z):   27271.970755 +/-  0.026671
# Acceptance Rate:                        0.476190
# Replacements:                               6800
# Total Samples:                             14280
# Nested Sampling ln(Z):              27272.271530
# Importance Nested Sampling ln(Z):   27271.967029 +/-  0.026061
# Acceptance Rate:                        0.475002
# Replacements:                               6850
# Total Samples:                             14421
# Nested Sampling ln(Z):              27272.318003
# Importance Nested Sampling ln(Z):   27271.967179 +/-  0.025522
# Acceptance Rate:                        0.473154
# Replacements:                               6900
# Total Samples:                             14583
# Nested Sampling ln(Z):              27272.360997
# Importance Nested Sampling ln(Z):   27271.962676 +/-  0.025017
# Acceptance Rate:                        0.471890
# Replacements:                               6950
# Total Samples:                             14728
# Nested Sampling ln(Z):              27272.400744
# Importance Nested Sampling ln(Z):   27271.966892 +/-  0.024549
# Acceptance Rate:                        0.470493
# Replacements:                               7000
# Total Samples:                             14878
# Nested Sampling ln(Z):              27272.437205
# Importance Nested Sampling ln(Z):   27271.971145 +/-  0.024134
# Acceptance Rate:                        0.469875
# Replacements:                               7050
# Total Samples:                             15004
# Nested Sampling ln(Z):              27272.470970
# Importance Nested Sampling ln(Z):   27271.979506 +/-  0.023760
# Acceptance Rate:                        0.468245
# Replacements:                               7100
# Total Samples:                             15163
# Nested Sampling ln(Z):              27272.502757
# Importance Nested Sampling ln(Z):   27271.977495 +/-  0.023429
# Acceptance Rate:                        0.467290
# Replacements:                               7150
# Total Samples:                             15301
# Nested Sampling ln(Z):              27272.532418
# Importance Nested Sampling ln(Z):   27271.977040 +/-  0.023185
# Acceptance Rate:                        0.466261
# Replacements:                               7200
# Total Samples:                             15442
# Nested Sampling ln(Z):              27272.559885
# Importance Nested Sampling ln(Z):   27271.979343 +/-  0.022924
# Acceptance Rate:                        0.465370
# Replacements:                               7250
# Total Samples:                             15579
# Nested Sampling ln(Z):              27272.585429
# Importance Nested Sampling ln(Z):   27271.980571 +/-  0.022695
# Acceptance Rate:                        0.465146
# Replacements:                               7300
# Total Samples:                             15694
# Nested Sampling ln(Z):              27272.609077
# Importance Nested Sampling ln(Z):   27271.982288 +/-  0.022510
# Acceptance Rate:                        0.463518
# Replacements:                               7350
# Total Samples:                             15857
# Nested Sampling ln(Z):              27272.631292
# Importance Nested Sampling ln(Z):   27271.983169 +/-  0.022315
# Acceptance Rate:                        0.462182
# Replacements:                               7400
# Total Samples:                             16011
# Nested Sampling ln(Z):              27272.652077
# Importance Nested Sampling ln(Z):   27271.980086 +/-  0.022226
# Acceptance Rate:                        0.461129
# Replacements:                               7450
# Total Samples:                             16156
# Nested Sampling ln(Z):              27272.671365
# Importance Nested Sampling ln(Z):   27271.980089 +/-  0.022102
# Acceptance Rate:                        0.459953
# Replacements:                               7500
# Total Samples:                             16306
# Nested Sampling ln(Z):              27272.689153
# Importance Nested Sampling ln(Z):   27271.979316 +/-  0.022011
# Acceptance Rate:                        0.458810
# Replacements:                               7541
# Total Samples:                             16436
# Nested Sampling ln(Z):              27272.702792
# Importance Nested Sampling ln(Z):   27271.981145 +/-  0.021906
#  ln(ev)=   27272.913143504091      +/-  0.14728928658827045
#  Total Likelihood Evaluations:        16436
#  Sampling finished. Exiting MultiNest
#   analysing data from juliet/juliet_oot_exp/jomnest_.txt

# %% [markdown]
# ## Full GP fitting

# %%
# Now we will use posteriors from GP parameters as priors in next full GP fitting
# This will give us the priors on GP parameters
for i in range(len(params_gp)):
    post1 = res_gp_only.posteriors['posterior_samples'][params_gp[i]]
    mu, sig = np.median(post1), np.std(post1)
    dist_gp[i] = 'truncatednormal'
    hyper_gp[i] = [mu, sig, hyper_gp[i][0], hyper_gp[i][1]]

# Doing the same for instrumental parameters
# For sigma_w_CHEOPS
dist_ins[2] = 'truncatednormal'
post2 = res_gp_only.posteriors['posterior_samples']['sigma_w_CHEOPS']
mu, sig = np.median(post2), np.std(post2)
hyper_ins[2] = [mu, sig, hyper_ins[2][0], hyper_ins[2][1]]
# For mflux
dist_ins[1] = 'normal'
post2 = res_gp_only.posteriors['posterior_samples']['mflux_CHEOPS']
mu, sig = np.median(post2), np.std(post2)
hyper_ins[1] = [mu, sig]

# Defining planetary parameters
params_P = ['P_p1', 't0_p1', 'r1_p1', 'r2_p1', 'q1_CHEOPS', 'q2_CHEOPS', 'ecc_p1', 'omega_p1', 'a_p1']
dist_P = ['fixed', 'normal', 'uniform', 'uniform', 'fixed', 'fixed', 'fixed', 'fixed', 'fixed']
hyper_P = [P, [T_ec, 0.1], [0.,1.], [0.,1.], 0., 0., 0., 270., 4.71779818]

## Making prior dictionary
params = params_P + params_ins + params_gp
dist = dist_P + dist_ins + dist_gp
hyper = hyper_P + hyper_ins + hyper_gp

for i, j, k in zip(params, dist, hyper):
    priors[i] = {}
    priors[i]['distribution'], priors[i]['hyperparameters'] = j, k

# And fitting
data_full = jl.load(priors=priors, t_lc=tim_full, y_lc=fl_full, yerr_lc=fle_full, GP_regressors_lc=tim_full, out_folder='juliet/juliet_full_exp')
results_full = data_full.fit(n_live_points=500, verbose=True)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  500
#  dimensionality =    9
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.996377
# Replacements:                                550
# Total Samples:                               552
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29666.144921 +/-  0.997446
# Acceptance Rate:                        0.985222
# Replacements:                                600
# Total Samples:                               609
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29666.046651 +/-  0.997531
# Acceptance Rate:                        0.955882
# Replacements:                                650
# Total Samples:                               680
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29665.936376 +/-  0.997617
# Acceptance Rate:                        0.919842
# Replacements:                                700
# Total Samples:                               761
# Nested Sampling ln(Z):            -949567.092180
# Importance Nested Sampling ln(Z):   29665.823835 +/-  0.997695
# Acceptance Rate:                        0.902527
# Replacements:                                750
# Total Samples:                               831
# Nested Sampling ln(Z):            -686179.841016
# Importance Nested Sampling ln(Z):   29665.736517 +/-  0.997074
# Acceptance Rate:                        0.869565
# Replacements:                                800
# Total Samples:                               920
# Nested Sampling ln(Z):            -401044.839678
# Importance Nested Sampling ln(Z):   29667.029627 +/-  0.715146
# Acceptance Rate:                        0.834971
# Replacements:                                850
# Total Samples:                              1018
# Nested Sampling ln(Z):            -280879.829221
# Importance Nested Sampling ln(Z):   29666.550614 +/-  0.715219
# Acceptance Rate:                        0.821918
# Replacements:                                900
# Total Samples:                              1095
# Nested Sampling ln(Z):            -186800.596787
# Importance Nested Sampling ln(Z):   29677.656363 +/-  0.999536
# Acceptance Rate:                        0.811966
# Replacements:                                950
# Total Samples:                              1170
# Nested Sampling ln(Z):            -113611.459652
# Importance Nested Sampling ln(Z):   29677.410480 +/-  0.999373
# Acceptance Rate:                        0.798085
# Replacements:                               1000
# Total Samples:                              1253
# Nested Sampling ln(Z):             -71016.524839
# Importance Nested Sampling ln(Z):   29677.410703 +/-  0.999178
# Acceptance Rate:                        0.784753
# Replacements:                               1050
# Total Samples:                              1338
# Nested Sampling ln(Z):             -48118.600266
# Importance Nested Sampling ln(Z):   29678.781811 +/-  0.787682
# Acceptance Rate:                        0.773558
# Replacements:                               1100
# Total Samples:                              1422
# Nested Sampling ln(Z):             -26401.988778
# Importance Nested Sampling ln(Z):   29678.756476 +/-  0.701207
# Acceptance Rate:                        0.766156
# Replacements:                               1150
# Total Samples:                              1501
# Nested Sampling ln(Z):              -9216.501969
# Importance Nested Sampling ln(Z):   29678.642957 +/-  0.682811
# Acceptance Rate:                        0.759494
# Replacements:                               1200
# Total Samples:                              1580
# Nested Sampling ln(Z):               1195.771320
# Importance Nested Sampling ln(Z):   29679.281710 +/-  0.610222
# Acceptance Rate:                        0.748951
# Replacements:                               1250
# Total Samples:                              1669
# Nested Sampling ln(Z):               9097.949495
# Importance Nested Sampling ln(Z):   29679.125788 +/-  0.594493
# Acceptance Rate:                        0.745413
# Replacements:                               1300
# Total Samples:                              1744
# Nested Sampling ln(Z):              13609.284132
# Importance Nested Sampling ln(Z):   29679.107880 +/-  0.539822
# Acceptance Rate:                        0.739726
# Replacements:                               1350
# Total Samples:                              1825
# Nested Sampling ln(Z):              17813.012157
# Importance Nested Sampling ln(Z):   29679.000303 +/-  0.531548
# Acceptance Rate:                        0.726141
# Replacements:                               1400
# Total Samples:                              1928
# Nested Sampling ln(Z):              20490.025039
# Importance Nested Sampling ln(Z):   29679.242212 +/-  0.471816
# Acceptance Rate:                        0.712181
# Replacements:                               1450
# Total Samples:                              2036
# Nested Sampling ln(Z):              22694.391740
# Importance Nested Sampling ln(Z):   29680.165991 +/-  0.626257
# Acceptance Rate:                        0.705882
# Replacements:                               1500
# Total Samples:                              2125
# Nested Sampling ln(Z):              24519.857119
# Importance Nested Sampling ln(Z):   29680.062170 +/-  0.620976
# Acceptance Rate:                        0.694133
# Replacements:                               1550
# Total Samples:                              2233
# Nested Sampling ln(Z):              25979.126836
# Importance Nested Sampling ln(Z):   29680.128382 +/-  0.537879
# Acceptance Rate:                        0.681141
# Replacements:                               1600
# Total Samples:                              2349
# Nested Sampling ln(Z):              26733.091298
# Importance Nested Sampling ln(Z):   29680.002589 +/-  0.531193
# Acceptance Rate:                        0.675952
# Replacements:                               1650
# Total Samples:                              2441
# Nested Sampling ln(Z):              27378.664657
# Importance Nested Sampling ln(Z):   29679.941529 +/-  0.508493
# Acceptance Rate:                        0.671671
# Replacements:                               1700
# Total Samples:                              2531
# Nested Sampling ln(Z):              27939.791977
# Importance Nested Sampling ln(Z):   29679.850353 +/-  0.503874
# Acceptance Rate:                        0.668449
# Replacements:                               1750
# Total Samples:                              2618
# Nested Sampling ln(Z):              28348.209434
# Importance Nested Sampling ln(Z):   29680.081654 +/-  0.453954
# Acceptance Rate:                        0.662739
# Replacements:                               1800
# Total Samples:                              2716
# Nested Sampling ln(Z):              28715.769320
# Importance Nested Sampling ln(Z):   29679.981406 +/-  0.450407
# Acceptance Rate:                        0.658363
# Replacements:                               1850
# Total Samples:                              2810
# Nested Sampling ln(Z):              28946.104461
# Importance Nested Sampling ln(Z):   29680.067037 +/-  0.396022
# Acceptance Rate:                        0.658579
# Replacements:                               1900
# Total Samples:                              2885
# Nested Sampling ln(Z):              29095.823009
# Importance Nested Sampling ln(Z):   29679.981929 +/-  0.392926
# Acceptance Rate:                        0.654362
# Replacements:                               1950
# Total Samples:                              2980
# Nested Sampling ln(Z):              29237.310019
# Importance Nested Sampling ln(Z):   29679.909052 +/-  0.385509
# Acceptance Rate:                        0.652529
# Replacements:                               2000
# Total Samples:                              3065
# Nested Sampling ln(Z):              29315.631679
# Importance Nested Sampling ln(Z):   29680.254997 +/-  0.378294
# Acceptance Rate:                        0.652658
# Replacements:                               2050
# Total Samples:                              3141
# Nested Sampling ln(Z):              29380.655658
# Importance Nested Sampling ln(Z):   29680.227762 +/-  0.357042
# Acceptance Rate:                        0.651971
# Replacements:                               2100
# Total Samples:                              3221
# Nested Sampling ln(Z):              29438.962756
# Importance Nested Sampling ln(Z):   29680.269560 +/-  0.324119
# Acceptance Rate:                        0.649940
# Replacements:                               2150
# Total Samples:                              3308
# Nested Sampling ln(Z):              29488.301522
# Importance Nested Sampling ln(Z):   29680.268932 +/-  0.305730
# Acceptance Rate:                        0.647059
# Replacements:                               2200
# Total Samples:                              3400
# Nested Sampling ln(Z):              29521.877774
# Importance Nested Sampling ln(Z):   29680.338265 +/-  0.279220
# Acceptance Rate:                        0.645069
# Replacements:                               2250
# Total Samples:                              3488
# Nested Sampling ln(Z):              29552.100308
# Importance Nested Sampling ln(Z):   29680.312483 +/-  0.264882
# Acceptance Rate:                        0.639600
# Replacements:                               2300
# Total Samples:                              3596
# Nested Sampling ln(Z):              29571.772283
# Importance Nested Sampling ln(Z):   29680.261179 +/-  0.253174
# Acceptance Rate:                        0.632230
# Replacements:                               2350
# Total Samples:                              3717
# Nested Sampling ln(Z):              29591.631015
# Importance Nested Sampling ln(Z):   29680.186903 +/-  0.247462
# Acceptance Rate:                        0.630252
# Replacements:                               2400
# Total Samples:                              3808
# Nested Sampling ln(Z):              29603.459759
# Importance Nested Sampling ln(Z):   29680.138151 +/-  0.239754
# Acceptance Rate:                        0.629820
# Replacements:                               2450
# Total Samples:                              3890
# Nested Sampling ln(Z):              29615.552342
# Importance Nested Sampling ln(Z):   29680.124387 +/-  0.229335
# Acceptance Rate:                        0.627983
# Replacements:                               2500
# Total Samples:                              3981
# Nested Sampling ln(Z):              29624.189940
# Importance Nested Sampling ln(Z):   29680.079589 +/-  0.223483
# Acceptance Rate:                        0.624541
# Replacements:                               2550
# Total Samples:                              4083
# Nested Sampling ln(Z):              29632.966548
# Importance Nested Sampling ln(Z):   29680.044385 +/-  0.211308
# Acceptance Rate:                        0.620229
# Replacements:                               2600
# Total Samples:                              4192
# Nested Sampling ln(Z):              29640.815472
# Importance Nested Sampling ln(Z):   29680.014606 +/-  0.198917
# Acceptance Rate:                        0.618148
# Replacements:                               2650
# Total Samples:                              4287
# Nested Sampling ln(Z):              29646.868653
# Importance Nested Sampling ln(Z):   29679.998761 +/-  0.190174
# Acceptance Rate:                        0.618698
# Replacements:                               2700
# Total Samples:                              4364
# Nested Sampling ln(Z):              29651.203179
# Importance Nested Sampling ln(Z):   29679.977561 +/-  0.185982
# Acceptance Rate:                        0.611111
# Replacements:                               2750
# Total Samples:                              4500
# Nested Sampling ln(Z):              29655.746555
# Importance Nested Sampling ln(Z):   29680.062509 +/-  0.184543
# Acceptance Rate:                        0.606586
# Replacements:                               2800
# Total Samples:                              4616
# Nested Sampling ln(Z):              29659.367211
# Importance Nested Sampling ln(Z):   29680.045386 +/-  0.175544
# Acceptance Rate:                        0.604070
# Replacements:                               2850
# Total Samples:                              4718
# Nested Sampling ln(Z):              29662.148969
# Importance Nested Sampling ln(Z):   29680.054684 +/-  0.167883
# Acceptance Rate:                        0.600166
# Replacements:                               2900
# Total Samples:                              4832
# Nested Sampling ln(Z):              29664.433484
# Importance Nested Sampling ln(Z):   29680.134202 +/-  0.172825
# Acceptance Rate:                        0.598013
# Replacements:                               2950
# Total Samples:                              4933
# Nested Sampling ln(Z):              29666.648782
# Importance Nested Sampling ln(Z):   29680.263168 +/-  0.203467
# Acceptance Rate:                        0.592885
# Replacements:                               3000
# Total Samples:                              5060
# Nested Sampling ln(Z):              29668.894090
# Importance Nested Sampling ln(Z):   29680.303281 +/-  0.183340
# Acceptance Rate:                        0.590170
# Replacements:                               3050
# Total Samples:                              5168
# Nested Sampling ln(Z):              29670.701931
# Importance Nested Sampling ln(Z):   29680.263543 +/-  0.177349
# Acceptance Rate:                        0.585679
# Replacements:                               3100
# Total Samples:                              5293
# Nested Sampling ln(Z):              29672.252484
# Importance Nested Sampling ln(Z):   29680.275441 +/-  0.170237
# Acceptance Rate:                        0.582363
# Replacements:                               3150
# Total Samples:                              5409
# Nested Sampling ln(Z):              29673.437995
# Importance Nested Sampling ln(Z):   29680.254107 +/-  0.161422
# Acceptance Rate:                        0.578767
# Replacements:                               3200
# Total Samples:                              5529
# Nested Sampling ln(Z):              29674.539105
# Importance Nested Sampling ln(Z):   29680.281017 +/-  0.149740
# Acceptance Rate:                        0.575119
# Replacements:                               3250
# Total Samples:                              5651
# Nested Sampling ln(Z):              29675.410693
# Importance Nested Sampling ln(Z):   29680.250695 +/-  0.144253
# Acceptance Rate:                        0.569260
# Replacements:                               3300
# Total Samples:                              5797
# Nested Sampling ln(Z):              29676.110912
# Importance Nested Sampling ln(Z):   29680.269548 +/-  0.134216
# Acceptance Rate:                        0.564448
# Replacements:                               3350
# Total Samples:                              5935
# Nested Sampling ln(Z):              29676.715438
# Importance Nested Sampling ln(Z):   29680.259065 +/-  0.127554
# Acceptance Rate:                        0.561334
# Replacements:                               3400
# Total Samples:                              6057
# Nested Sampling ln(Z):              29677.273384
# Importance Nested Sampling ln(Z):   29680.269187 +/-  0.120740
# Acceptance Rate:                        0.560611
# Replacements:                               3450
# Total Samples:                              6154
# Nested Sampling ln(Z):              29677.740719
# Importance Nested Sampling ln(Z):   29680.323621 +/-  0.120243
# Acceptance Rate:                        0.555909
# Replacements:                               3500
# Total Samples:                              6296
# Nested Sampling ln(Z):              29678.150526
# Importance Nested Sampling ln(Z):   29680.362384 +/-  0.125528
# Acceptance Rate:                        0.550986
# Replacements:                               3550
# Total Samples:                              6443
# Nested Sampling ln(Z):              29678.517531
# Importance Nested Sampling ln(Z):   29680.340642 +/-  0.119682
# Acceptance Rate:                        0.544629
# Replacements:                               3600
# Total Samples:                              6610
# Nested Sampling ln(Z):              29678.846987
# Importance Nested Sampling ln(Z):   29680.324970 +/-  0.113398
# Acceptance Rate:                        0.540821
# Replacements:                               3650
# Total Samples:                              6749
# Nested Sampling ln(Z):              29679.139733
# Importance Nested Sampling ln(Z):   29680.347968 +/-  0.116738
# Acceptance Rate:                        0.535223
# Replacements:                               3700
# Total Samples:                              6913
# Nested Sampling ln(Z):              29679.394990
# Importance Nested Sampling ln(Z):   29680.331815 +/-  0.111100
# Acceptance Rate:                        0.530335
# Replacements:                               3750
# Total Samples:                              7071
# Nested Sampling ln(Z):              29679.616533
# Importance Nested Sampling ln(Z):   29680.330376 +/-  0.107034
# Acceptance Rate:                        0.525733
# Replacements:                               3800
# Total Samples:                              7228
# Nested Sampling ln(Z):              29679.811861
# Importance Nested Sampling ln(Z):   29680.346457 +/-  0.108778
# Acceptance Rate:                        0.520200
# Replacements:                               3850
# Total Samples:                              7401
# Nested Sampling ln(Z):              29679.983608
# Importance Nested Sampling ln(Z):   29680.335901 +/-  0.104632
# Acceptance Rate:                        0.513969
# Replacements:                               3900
# Total Samples:                              7588
# Nested Sampling ln(Z):              29680.137568
# Importance Nested Sampling ln(Z):   29680.348195 +/-  0.099182
# Acceptance Rate:                        0.504212
# Replacements:                               3950
# Total Samples:                              7834
# Nested Sampling ln(Z):              29680.273742
# Importance Nested Sampling ln(Z):   29680.317890 +/-  0.096430
# Acceptance Rate:                        0.493705
# Replacements:                               4000
# Total Samples:                              8102
# Nested Sampling ln(Z):              29680.395999
# Importance Nested Sampling ln(Z):   29680.287637 +/-  0.094457
# Acceptance Rate:                        0.490374
# Replacements:                               4050
# Total Samples:                              8259
# Nested Sampling ln(Z):              29680.505551
# Importance Nested Sampling ln(Z):   29680.272353 +/-  0.093255
# Acceptance Rate:                        0.484119
# Replacements:                               4100
# Total Samples:                              8469
# Nested Sampling ln(Z):              29680.603900
# Importance Nested Sampling ln(Z):   29680.266606 +/-  0.091280
# Acceptance Rate:                        0.477560
# Replacements:                               4150
# Total Samples:                              8690
# Nested Sampling ln(Z):              29680.692695
# Importance Nested Sampling ln(Z):   29680.276049 +/-  0.089169
# Acceptance Rate:                        0.470694
# Replacements:                               4200
# Total Samples:                              8923
# Nested Sampling ln(Z):              29680.772681
# Importance Nested Sampling ln(Z):   29680.275543 +/-  0.089583
# Acceptance Rate:                        0.461756
# Replacements:                               4250
# Total Samples:                              9204
# Nested Sampling ln(Z):              29680.844836
# Importance Nested Sampling ln(Z):   29680.252485 +/-  0.088795
# Acceptance Rate:                        0.450168
# Replacements:                               4300
# Total Samples:                              9552
# Nested Sampling ln(Z):              29680.910075
# Importance Nested Sampling ln(Z):   29680.220898 +/-  0.089020
# Acceptance Rate:                        0.442658
# Replacements:                               4350
# Total Samples:                              9827
# Nested Sampling ln(Z):              29680.968853
# Importance Nested Sampling ln(Z):   29680.230699 +/-  0.088157
# Acceptance Rate:                        0.435514
# Replacements:                               4400
# Total Samples:                             10103
# Nested Sampling ln(Z):              29681.021984
# Importance Nested Sampling ln(Z):   29680.222071 +/-  0.087457
# Acceptance Rate:                        0.427885
# Replacements:                               4450
# Total Samples:                             10400
# Nested Sampling ln(Z):              29681.070629
# Importance Nested Sampling ln(Z):   29680.211036 +/-  0.087123
# Acceptance Rate:                        0.418722
# Replacements:                               4500
# Total Samples:                             10747
# Nested Sampling ln(Z):              29681.115506
# Importance Nested Sampling ln(Z):   29680.216494 +/-  0.086544
# Acceptance Rate:                        0.411504
# Replacements:                               4550
# Total Samples:                             11057
# Nested Sampling ln(Z):              29681.156539
# Importance Nested Sampling ln(Z):   29680.223548 +/-  0.085788
# Acceptance Rate:                        0.399618
# Replacements:                               4600
# Total Samples:                             11511
# Nested Sampling ln(Z):              29681.194094
# Importance Nested Sampling ln(Z):   29680.218053 +/-  0.085179
# Acceptance Rate:                        0.389480
# Replacements:                               4650
# Total Samples:                             11939
# Nested Sampling ln(Z):              29681.228406
# Importance Nested Sampling ln(Z):   29680.215589 +/-  0.084813
# Acceptance Rate:                        0.381184
# Replacements:                               4700
# Total Samples:                             12330
# Nested Sampling ln(Z):              29681.259897
# Importance Nested Sampling ln(Z):   29680.214615 +/-  0.084447
# Acceptance Rate:                        0.369305
# Replacements:                               4750
# Total Samples:                             12862
# Nested Sampling ln(Z):              29681.288995
# Importance Nested Sampling ln(Z):   29680.214215 +/-  0.084152
# Acceptance Rate:                        0.361582
# Replacements:                               4800
# Total Samples:                             13275
# Nested Sampling ln(Z):              29681.316034
# Importance Nested Sampling ln(Z):   29680.216031 +/-  0.083660
# Acceptance Rate:                        0.351449
# Replacements:                               4850
# Total Samples:                             13800
# Nested Sampling ln(Z):              29681.341260
# Importance Nested Sampling ln(Z):   29680.214479 +/-  0.083598
# Acceptance Rate:                        0.340964
# Replacements:                               4900
# Total Samples:                             14371
# Nested Sampling ln(Z):              29681.365034
# Importance Nested Sampling ln(Z):   29680.216181 +/-  0.083276
# Acceptance Rate:                        0.329254
# Replacements:                               4950
# Total Samples:                             15034
# Nested Sampling ln(Z):              29681.387715
# Importance Nested Sampling ln(Z):   29680.209497 +/-  0.083547
# Acceptance Rate:                        0.321564
# Replacements:                               5000
# Total Samples:                             15549
# Nested Sampling ln(Z):              29681.409091
# Importance Nested Sampling ln(Z):   29680.219728 +/-  0.082682
# Acceptance Rate:                        0.309968
# Replacements:                               5050
# Total Samples:                             16292
# Nested Sampling ln(Z):              29681.429179
# Importance Nested Sampling ln(Z):   29680.218402 +/-  0.082580
# Acceptance Rate:                        0.300849
# Replacements:                               5100
# Total Samples:                             16952
# Nested Sampling ln(Z):              29681.448321
# Importance Nested Sampling ln(Z):   29680.235451 +/-  0.081673
# Acceptance Rate:                        0.289098
# Replacements:                               5150
# Total Samples:                             17814
# Nested Sampling ln(Z):              29681.466604
# Importance Nested Sampling ln(Z):   29680.241340 +/-  0.080995
# Acceptance Rate:                        0.282241
# Replacements:                               5200
# Total Samples:                             18424
# Nested Sampling ln(Z):              29681.484514
# Importance Nested Sampling ln(Z):   29680.251990 +/-  0.080279
# Acceptance Rate:                        0.272968
# Replacements:                               5250
# Total Samples:                             19233
# Nested Sampling ln(Z):              29681.502084
# Importance Nested Sampling ln(Z):   29680.256809 +/-  0.079731
# Acceptance Rate:                        0.266720
# Replacements:                               5300
# Total Samples:                             19871
# Nested Sampling ln(Z):              29681.518929
# Importance Nested Sampling ln(Z):   29680.270727 +/-  0.078669
# Acceptance Rate:                        0.256435
# Replacements:                               5350
# Total Samples:                             20863
# Nested Sampling ln(Z):              29681.535367
# Importance Nested Sampling ln(Z):   29680.284025 +/-  0.077829
# Acceptance Rate:                        0.250499
# Replacements:                               5400
# Total Samples:                             21557
# Nested Sampling ln(Z):              29681.551298
# Importance Nested Sampling ln(Z):   29680.288347 +/-  0.077353
# Acceptance Rate:                        0.242989
# Replacements:                               5450
# Total Samples:                             22429
# Nested Sampling ln(Z):              29681.567026
# Importance Nested Sampling ln(Z):   29680.286116 +/-  0.077336
# Acceptance Rate:                        0.235334
# Replacements:                               5500
# Total Samples:                             23371
# Nested Sampling ln(Z):              29681.582426
# Importance Nested Sampling ln(Z):   29680.287160 +/-  0.077165
# Acceptance Rate:                        0.230846
# Replacements:                               5550
# Total Samples:                             24042
# Nested Sampling ln(Z):              29681.597858
# Importance Nested Sampling ln(Z):   29680.295350 +/-  0.076517
# Acceptance Rate:                        0.223803
# Replacements:                               5600
# Total Samples:                             25022
# Nested Sampling ln(Z):              29681.613093
# Importance Nested Sampling ln(Z):   29680.297265 +/-  0.076288
# Acceptance Rate:                        0.215871
# Replacements:                               5650
# Total Samples:                             26173
# Nested Sampling ln(Z):              29681.628283
# Importance Nested Sampling ln(Z):   29680.299453 +/-  0.076045
# Acceptance Rate:                        0.212314
# Replacements:                               5700
# Total Samples:                             26847
# Nested Sampling ln(Z):              29681.643605
# Importance Nested Sampling ln(Z):   29680.302239 +/-  0.075789
# Acceptance Rate:                        0.209220
# Replacements:                               5750
# Total Samples:                             27483
# Nested Sampling ln(Z):              29681.659401
# Importance Nested Sampling ln(Z):   29680.306384 +/-  0.075435
# Acceptance Rate:                        0.207930
# Replacements:                               5800
# Total Samples:                             27894
# Nested Sampling ln(Z):              29681.675646
# Importance Nested Sampling ln(Z):   29680.314125 +/-  0.074850
# Acceptance Rate:                        0.207160
# Replacements:                               5850
# Total Samples:                             28239
# Nested Sampling ln(Z):              29681.692112
# Importance Nested Sampling ln(Z):   29680.322626 +/-  0.074207
# Acceptance Rate:                        0.206669
# Replacements:                               5900
# Total Samples:                             28548
# Nested Sampling ln(Z):              29681.708542
# Importance Nested Sampling ln(Z):   29680.334694 +/-  0.073336
# Acceptance Rate:                        0.205925
# Replacements:                               5950
# Total Samples:                             28894
# Nested Sampling ln(Z):              29681.725200
# Importance Nested Sampling ln(Z):   29680.344494 +/-  0.072634
# Acceptance Rate:                        0.205346
# Replacements:                               6000
# Total Samples:                             29219
# Nested Sampling ln(Z):              29681.742134
# Importance Nested Sampling ln(Z):   29680.352867 +/-  0.072025
# Acceptance Rate:                        0.204932
# Replacements:                               6050
# Total Samples:                             29522
# Nested Sampling ln(Z):              29681.759536
# Importance Nested Sampling ln(Z):   29680.361900 +/-  0.071370
# Acceptance Rate:                        0.204904
# Replacements:                               6100
# Total Samples:                             29770
# Nested Sampling ln(Z):              29681.777219
# Importance Nested Sampling ln(Z):   29680.371788 +/-  0.070670
# Acceptance Rate:                        0.205082
# Replacements:                               6150
# Total Samples:                             29988
# Nested Sampling ln(Z):              29681.794990
# Importance Nested Sampling ln(Z):   29680.382195 +/-  0.069944
# Acceptance Rate:                        0.204823
# Replacements:                               6200
# Total Samples:                             30270
# Nested Sampling ln(Z):              29681.812574
# Importance Nested Sampling ln(Z):   29680.389859 +/-  0.069393
# Acceptance Rate:                        0.204703
# Replacements:                               6250
# Total Samples:                             30532
# Nested Sampling ln(Z):              29681.830077
# Importance Nested Sampling ln(Z):   29680.399825 +/-  0.068702
# Acceptance Rate:                        0.205238
# Replacements:                               6300
# Total Samples:                             30696
# Nested Sampling ln(Z):              29681.847179
# Importance Nested Sampling ln(Z):   29680.412677 +/-  0.067837
# Acceptance Rate:                        0.205928
# Replacements:                               6350
# Total Samples:                             30836
# Nested Sampling ln(Z):              29681.863712
# Importance Nested Sampling ln(Z):   29680.423963 +/-  0.067081
# Acceptance Rate:                        0.206398
# Replacements:                               6400
# Total Samples:                             31008
# Nested Sampling ln(Z):              29681.879901
# Importance Nested Sampling ln(Z):   29680.435807 +/-  0.066288
# Acceptance Rate:                        0.206996
# Replacements:                               6450
# Total Samples:                             31160
# Nested Sampling ln(Z):              29681.895893
# Importance Nested Sampling ln(Z):   29680.447896 +/-  0.065505
# Acceptance Rate:                        0.207363
# Replacements:                               6500
# Total Samples:                             31346
# Nested Sampling ln(Z):              29681.911385
# Importance Nested Sampling ln(Z):   29680.456807 +/-  0.064911
# Acceptance Rate:                        0.208029
# Replacements:                               6550
# Total Samples:                             31486
# Nested Sampling ln(Z):              29681.926219
# Importance Nested Sampling ln(Z):   29680.467225 +/-  0.064246
# Acceptance Rate:                        0.208742
# Replacements:                               6600
# Total Samples:                             31618
# Nested Sampling ln(Z):              29681.940525
# Importance Nested Sampling ln(Z):   29680.476169 +/-  0.063674
# Acceptance Rate:                        0.209258
# Replacements:                               6650
# Total Samples:                             31779
# Nested Sampling ln(Z):              29681.954440
# Importance Nested Sampling ln(Z):   29680.486214 +/-  0.063039
# Acceptance Rate:                        0.209683
# Replacements:                               6700
# Total Samples:                             31953
# Nested Sampling ln(Z):              29681.967604
# Importance Nested Sampling ln(Z):   29680.495771 +/-  0.062434
# Acceptance Rate:                        0.210431
# Replacements:                               6750
# Total Samples:                             32077
# Nested Sampling ln(Z):              29681.980079
# Importance Nested Sampling ln(Z):   29680.506087 +/-  0.061802
# Acceptance Rate:                        0.211042
# Replacements:                               6800
# Total Samples:                             32221
# Nested Sampling ln(Z):              29681.992083
# Importance Nested Sampling ln(Z):   29680.516766 +/-  0.061148
# Acceptance Rate:                        0.211478
# Replacements:                               6850
# Total Samples:                             32391
# Nested Sampling ln(Z):              29682.003654
# Importance Nested Sampling ln(Z):   29680.527117 +/-  0.060511
# Acceptance Rate:                        0.212053
# Replacements:                               6900
# Total Samples:                             32539
# Nested Sampling ln(Z):              29682.014826
# Importance Nested Sampling ln(Z):   29680.533354 +/-  0.060118
# Acceptance Rate:                        0.212675
# Replacements:                               6950
# Total Samples:                             32679
# Nested Sampling ln(Z):              29682.025586
# Importance Nested Sampling ln(Z):   29680.543064 +/-  0.059536
# Acceptance Rate:                        0.212991
# Replacements:                               6978
# Total Samples:                             32762
# Nested Sampling ln(Z):              29682.031474
# Importance Nested Sampling ln(Z):   29680.547153 +/-  0.059288
#  ln(ev)=   29682.195934777352      +/-  0.12326948616426815
#   analysing data from juliet/juliet_full_exp/jomnest_.txt Total Likelihood Evaluations:        32762
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# Let's plot the results...

# %%
# juliet best fit model
model = results_full.lc.evaluate('CHEOPS')

# Making a plot
fig = plt.figure(figsize=(16,9))
gs = gd.GridSpec(2,1, height_ratios=[2,1])

# Top panel
ax1 = plt.subplot(gs[0])
ax1.errorbar(tim_full['CHEOPS'], fl_full['CHEOPS'], yerr=fle_full['CHEOPS'], fmt='.', alpha=0.3)
ax1.plot(tim_full['CHEOPS'], model, c='k', zorder=100)
ax1.set_ylabel('Relative Flux')
ax1.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
ax1.xaxis.set_major_formatter(plt.NullFormatter())

# Bottom panel
ax2 = plt.subplot(gs[1])
ax2.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-model)*1e6, yerr=fle_full['CHEOPS']*1e6, fmt='.', alpha=0.3)
ax2.axhline(y=0.0, c='black', ls='--')
ax2.set_ylabel('Residuals (ppm)')
ax2.set_xlabel('Time (BJD)')
ax2.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
# Out:
# (0.5328613058663905, 3.047896259929985)

# %%
# juliet best fit GP el
gp_model = results_full.lc.model['CHEOPS']['GP']

# juliet best fit transit model and its errors
transit_model = results_full.lc.model['CHEOPS']['deterministic']
transit_model_err = results_full.lc.model['CHEOPS']['deterministic_errors']
umodel, lmodel = transit_model + transit_model_err, transit_model - transit_model_err

# Normalising the data and fitting
fac = 1/np.max(transit_model)

# Making a plot
fig = plt.figure(figsize=(16,9))
gs = gd.GridSpec(2,1, height_ratios=[2,1])

# Top panel
ax1 = plt.subplot(gs[0])
ax1.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-gp_model)*fac, yerr=fle_full['CHEOPS'], fmt='.', alpha=0.3)
ax1.plot(tim_full['CHEOPS'], transit_model*fac, c='k', zorder=100)
ax1.fill_between(tim_full['CHEOPS'], umodel*fac, lmodel*fac, color='red', alpha=0.7, zorder=5)
ax1.set_ylabel('Relative Flux')
ax1.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
ax1.xaxis.set_major_formatter(plt.NullFormatter())

# Bottom panel
ax2 = plt.subplot(gs[1])
ax2.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-gp_model-transit_model)*1e6*fac, yerr=fle_full['CHEOPS']*1e6, fmt='.', alpha=0.3)
ax2.axhline(y=0.0, c='black', ls='--')
ax2.set_ylabel('Residuals (ppm)')
ax2.set_xlabel('Time (BJD)')
ax2.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
# Out:
# (0.5328613058663905, 3.047896259929985)

# %% [markdown]
# It seems that the fit was good?! Let's check the evidence in favour of this

# %%
print(results_full.posteriors['lnZ'])
# Out:
# 29680.547152937663
