# %% [markdown]
# # Two step fitting of data using GP: Exponential-Matern Kernel
#
# This approach to fit data to the given data in two step is implemented in Patel & Espinoza (2021). The idea is to use Gaussian Processes to model the "extra" noise (apart from the transit signal) in the data. This method is in contrast to the method generally used in the analysis by `pycheops` which include *decorrelation* of instrumental parameters (because, we know their properties and can well correct for them). While in this approach we won't follow this --- instead we will directly fit GP noise model to the data. There is a caveat to this approach: if not handled properly, it can produce larger uncertainties in the retrieved planetary parameters (GP can try to fit transit signal as noise). So, what we will do is to fit only out-of-transit data points first (and thus excluding the transit signal). Next we can fit the whole dataset (or just the transit signal) with full model (transit model + GP model) with priors on GP hyperparameters as the posteriors found in the first step.
#
# We will use `juliet` to perform all of these tasks: the main reason for this is that, while `pycheops` can perform GP fitting, it doesn't include versatile GP kernels like Exponential-Matern kernel or Quasi-Periodic kernel. The kernel provided by `pycheops` is SHOTerm which is a simple harmonic oscillator kernel and not as versatile as Exp-Matern kernel or QP kernel. However, we still use `pycheops` to extract the transit lightcurve data.
#
# In the present notebook we will use Exponential-Matern kernel to demonstrate the fitting.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from dace.cheops import Cheops
import pycheops
from uncertainties import ufloat
from uncertainties.umath import sqrt as usqrt
import lmfit as lmf
import re
from pycheops.utils import phaser
import matplotlib.gridspec as gd
import juliet as jl
# Out:
# /home/jayshil/anaconda3/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py:20: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   int_types = {_np.int, _np.int8, _np.int16, _np.int32, _np.int64, _np.integer}

# %% [markdown]
# ## Downloading the data
#
# As mentioned, we are going to use `pycheops` to download the data and extracting time, flux and uncertainties in flux from the data.

# %%
# Downloading data
dd = pycheops.Dataset('CH_PR100036_TG000701_V0200')
tim, fl, fle = dd.get_lightcurve(aperture='DEFAULT', decontaminate=True)#, reject_highpoints=True)

# To clip outliers (I would, in general, not prefer using this)
tim, fl, fle = dd.clip_outliers(verbose=True);

# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Transit lightcurve for WASP-189b (Aperture: DEFAULT)')
plt.grid()
# Out:
# Found archive tgzfile /home/jayshil/.local/share/pycheops/CH_PR100036_TG000701_V0200.tgz
#  PI name     : Brice-Olivier DEMORY
#  OBS ID      : 1145201
#  Target      : WASP-189
#  Coordinates : 15:02:44.87 -03:01:53.0
#  Spec. type  : A6V
#  G magnitude : 6.55 +- 0.00
# Light curve data loaded from  /home/jayshil/.local/share/pycheops/CH_PR100036_TG000701_V0200-DEFAULT.fits
# Time stored relative to BJD = 2459016
# Aperture radius used = 25 arcsec
# UTC start:  2020-06-15T18:07:40
# UTC end:    2020-06-18T21:07:01
# Visit duration: 269961 s
# Exposure time: 7 x 4.8 s
# Number of non-flagged data points: 4758
# Efficiency (non-flagged data): 59.2 %
# Light curve corrected for flux from background stars
# Mean counts = 140556171.2
# Median counts = 140629390.3
# RMS counts = 222219.7 [1580 ppm]
# Median standard error = 11901.2 [85 ppm]
# Median background = 262452 e-/pxl
# Mean contamination = 733.0 ppm
# Mean smearing correction = 60.4 ppm
#
# Rejected 12 points more than 5.0 x MAD = 356 ppm from the median

# %% [markdown]
# ### Planetary and Stellar Properties
#
# Let's now extract planetary and stellar properties from online database (this would be helpful in determining priors on fit).

# %%
# Using ExoCTK to get planetary properties
rprs = np.random.normal(0.060907361661750425, 0.003144594526637345, 10000)
dep, dep_err = np.mean((rprs**2)*1e6), np.std((rprs**2)*1e6)

"""
star = pycheops.StarProperties(dd.target)
print(star)
"""
teff = np.random.normal(8000, 80, 10000)
logg = np.random.normal(3.9, 0.2, 10000)
mh = np.random.normal(0.29, 0.13, 10000)
h1, h2 = np.zeros(10000), np.zeros(10000)
cdc = pycheops.ld.stagger_power2_interpolator('CHEOPS')
for i in range(len(teff)):
    c1, c2, h1[i], h2[i] = cdc(teff[i], logg[i], mh[i])

# %% [markdown]
# ## Renormalising the lightcurve
#
# Note that the out-of-transit points are not at unity --- we will thus perform renormalisation.

# %%
# This code is taken from the pycheops example notebook
P = 2.7240338
BJD_0 = 2456706.4558
cycle = round((dd.bjd_ref-BJD_0)/P)
T_0 = BJD_0 - dd.bjd_ref + (cycle+0)*P
T_1 = BJD_0 - dd.bjd_ref + (cycle+1)*P
T_ec = T_0 + (P/2)

D = dep/1e6  # Depth stored in ppm
W = 0.1819/P    # Width stored in days

try:
    f_c = 0.#np.sqrt(0.093)*np.sin(67.0*np.pi/180)
    f_s = 0.#np.sqrt(0.093)*np.cos(67.0*np.pi/180)
except:
    # From Pepper et al., 2017
    ecosw = 0.#ufloat(-0.004,0.05099)
    esinw = 0.#ufloat(0.031,0.055)
    ecc = usqrt(ecosw**2+esinw**2)
    f_s = 0.#esinw/usqrt(ecc)  # f_s = sqrt(e)sin(omega) = e.sin(omega)/sqrt(e)
    f_c = 0.#ecosw/usqrt(ecc)  # f_c = sqrt(e)cos(omega) = e.cos(omega)/sqrt(e)


# Let's take data from first transit only
mask1 = tim < T_0+(W*P/2)
mask2 = tim > T_1-(W*P/2)
mask = mask1 + mask2

tim, fl, fle = dd.mask_data(mask)
# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.axvline(T_ec, c='k')
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Eclipse lightcurve for WASP-189b (Aperture: OPTIMAL)')
plt.grid()
# Out:
# Masked 791 points

# %%
tim, fl, fle = dd.flatten(T_0, P*W)
# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered')
plt.axvline(T_ec, c='k')
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)')
plt.ylabel('Normalised Flux')
plt.title('Eclipse lightcurve for WASP-189b (Aperture: OPTIMAL)')
plt.grid()

# %%
# Data dictionary for out of transit
tim_oot, fl_oot, fle_oot = {}, {}, {}
mask = np.where(tim > (T_ec + (W*P/2)))[0]
mask = np.hstack((np.where(tim < (T_ec - (W*P/2)))[0], mask))
tim_oot['CHEOPS'], fl_oot['CHEOPS'], fle_oot['CHEOPS'] = tim[mask], fl[mask], fle[mask]

# Data dictionary for full dataset
tim_full, fl_full, fle_full = {}, {}, {}
tim_full['CHEOPS'], fl_full['CHEOPS'], fle_full['CHEOPS'] = tim, fl, fle

# Plotting the data
plt.figure(figsize=(16,9))
plt.errorbar(tim, fl, yerr=fle, fmt='.', c='orangered', label='All points')
plt.errorbar(tim[mask], fl[mask], yerr=fle[mask], fmt='.', c='cornflowerblue', alpha=0.5, label='Out-of-transit points')
plt.axvline(x=T_ec, c='k', lw=3)
plt.axvline(x=T_ec-(W*P/2), c='cornflowerblue', lw=3)
plt.axvline(x=T_ec+(W*P/2), c='cornflowerblue', lw=3)
plt.xlabel('Time (BJD)', fontsize=16)
plt.ylabel('Normalised Flux', fontsize=16)
plt.title('Eclipse lightcurve for WASP-189b (Aperture: DEFAULT)', fontsize=18)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

# %% [markdown]
# ## Fitting Out-of-transit lightcurve
#
# First we fit a GP model along with instrumental parameters to the out-of-transit parameters.

# %%
# Instrumental parameters
params_ins = ['mdilution_CHEOPS', 'mflux_CHEOPS', 'sigma_w_CHEOPS']
dist_ins = ['fixed', 'normal', 'loguniform']
hyper_ins = [1., [0., 0.1], [0.1, 10000.]]

# GP Params
params_gp = ['GP_B_CHEOPS', 'GP_C_CHEOPS', 'GP_L_CHEOPS', 'GP_Prot_CHEOPS']
dist_gp = ['loguniform', 'loguniform', 'loguniform','loguniform']
hyper_gp = [[1e-5,1e3], [1e-5,1e4], [1e-3, 1e3], [1.,1e2]]

## Performing GP fit
params_gp_only = params_ins + params_gp
dist_gp_only = dist_ins + dist_gp
hyper_gp_only = hyper_ins + hyper_gp

### Populating prior dict
priors = {}
for i, j, k in zip(params_gp_only, dist_gp_only, hyper_gp_only):
    priors[i] = {}
    priors[i]['distribution'], priors[i]['hyperparameters'] = j, k

## Running GP only fit
data = jl.load(priors=priors, t_lc=tim_oot, y_lc=fl_oot, yerr_lc=fle_oot, GP_regressors_lc=tim_oot, out_folder='juliet/juliet_oot_exp')
res_gp_only = data.fit(n_live_points = 500, verbose = True)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  500
#  dimensionality =    6
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.992780
# Replacements:                                550
# Total Samples:                               554
# Nested Sampling ln(Z):              -4278.200031
# Importance Nested Sampling ln(Z):   27249.872328 +/-  0.945354
# Acceptance Rate:                        0.975610
# Replacements:                                600
# Total Samples:                               615
# Nested Sampling ln(Z):                765.395753
# Importance Nested Sampling ln(Z):   27249.767870 +/-  0.945448
# Acceptance Rate:                        0.960118
# Replacements:                                650
# Total Samples:                               677
# Nested Sampling ln(Z):               4328.024514
# Importance Nested Sampling ln(Z):   27259.964718 +/-  0.999227
# Acceptance Rate:                        0.929615
# Replacements:                                700
# Total Samples:                               753
# Nested Sampling ln(Z):               7473.235342
# Importance Nested Sampling ln(Z):   27259.858324 +/-  0.999302
# Acceptance Rate:                        0.909091
# Replacements:                                750
# Total Samples:                               825
# Nested Sampling ln(Z):               9405.731827
# Importance Nested Sampling ln(Z):   27259.620626 +/-  0.996195
# Acceptance Rate:                        0.897868
# Replacements:                                800
# Total Samples:                               891
# Nested Sampling ln(Z):              11129.294911
# Importance Nested Sampling ln(Z):   27259.344179 +/-  0.996241
# Acceptance Rate:                        0.889121
# Replacements:                                850
# Total Samples:                               956
# Nested Sampling ln(Z):              12960.957885
# Importance Nested Sampling ln(Z):   27259.134555 +/-  0.996279
# Acceptance Rate:                        0.867888
# Replacements:                                900
# Total Samples:                              1037
# Nested Sampling ln(Z):              14266.139337
# Importance Nested Sampling ln(Z):   27258.905393 +/-  0.996320
# Acceptance Rate:                        0.856628
# Replacements:                                950
# Total Samples:                              1109
# Nested Sampling ln(Z):              15404.645269
# Importance Nested Sampling ln(Z):   27258.729197 +/-  0.996351
# Acceptance Rate:                        0.841043
# Replacements:                               1000
# Total Samples:                              1189
# Nested Sampling ln(Z):              16371.023579
# Importance Nested Sampling ln(Z):   27258.527761 +/-  0.996381
# Acceptance Rate:                        0.829384
# Replacements:                               1050
# Total Samples:                              1266
# Nested Sampling ln(Z):              17734.971608
# Importance Nested Sampling ln(Z):   27258.374133 +/-  0.996407
# Acceptance Rate:                        0.818452
# Replacements:                               1100
# Total Samples:                              1344
# Nested Sampling ln(Z):              18732.643292
# Importance Nested Sampling ln(Z):   27258.206792 +/-  0.996429
# Acceptance Rate:                        0.800278
# Replacements:                               1150
# Total Samples:                              1437
# Nested Sampling ln(Z):              19531.825167
# Importance Nested Sampling ln(Z):   27258.023614 +/-  0.996452
# Acceptance Rate:                        0.791035
# Replacements:                               1200
# Total Samples:                              1517
# Nested Sampling ln(Z):              20379.090265
# Importance Nested Sampling ln(Z):   27257.890151 +/-  0.996470
# Acceptance Rate:                        0.773515
# Replacements:                               1250
# Total Samples:                              1616
# Nested Sampling ln(Z):              21178.548537
# Importance Nested Sampling ln(Z):   27257.728114 +/-  0.996489
# Acceptance Rate:                        0.770142
# Replacements:                               1300
# Total Samples:                              1688
# Nested Sampling ln(Z):              21908.819036
# Importance Nested Sampling ln(Z):   27257.624348 +/-  0.996501
# Acceptance Rate:                        0.758427
# Replacements:                               1350
# Total Samples:                              1780
# Nested Sampling ln(Z):              22879.659744
# Importance Nested Sampling ln(Z):   27257.484723 +/-  0.996277
# Acceptance Rate:                        0.750268
# Replacements:                               1400
# Total Samples:                              1866
# Nested Sampling ln(Z):              23396.925126
# Importance Nested Sampling ln(Z):   27257.347345 +/-  0.996288
# Acceptance Rate:                        0.750129
# Replacements:                               1450
# Total Samples:                              1933
# Nested Sampling ln(Z):              23921.663069
# Importance Nested Sampling ln(Z):   27257.247027 +/-  0.996296
# Acceptance Rate:                        0.739645
# Replacements:                               1500
# Total Samples:                              2028
# Nested Sampling ln(Z):              24364.043639
# Importance Nested Sampling ln(Z):   27257.108346 +/-  0.996299
# Acceptance Rate:                        0.734597
# Replacements:                               1550
# Total Samples:                              2110
# Nested Sampling ln(Z):              24829.655880
# Importance Nested Sampling ln(Z):   27256.988446 +/-  0.994532
# Acceptance Rate:                        0.730260
# Replacements:                               1600
# Total Samples:                              2191
# Nested Sampling ln(Z):              25245.066340
# Importance Nested Sampling ln(Z):   27256.884745 +/-  0.994539
# Acceptance Rate:                        0.724956
# Replacements:                               1650
# Total Samples:                              2276
# Nested Sampling ln(Z):              25519.344650
# Importance Nested Sampling ln(Z):   27256.868501 +/-  0.895068
# Acceptance Rate:                        0.718512
# Replacements:                               1700
# Total Samples:                              2366
# Nested Sampling ln(Z):              25837.356085
# Importance Nested Sampling ln(Z):   27256.738497 +/-  0.895077
# Acceptance Rate:                        0.712831
# Replacements:                               1750
# Total Samples:                              2455
# Nested Sampling ln(Z):              26072.605094
# Importance Nested Sampling ln(Z):   27256.615520 +/-  0.895082
# Acceptance Rate:                        0.709779
# Replacements:                               1800
# Total Samples:                              2536
# Nested Sampling ln(Z):              26262.875921
# Importance Nested Sampling ln(Z):   27256.511923 +/-  0.895088
# Acceptance Rate:                        0.705837
# Replacements:                               1850
# Total Samples:                              2621
# Nested Sampling ln(Z):              26439.250438
# Importance Nested Sampling ln(Z):   27256.413814 +/-  0.891396
# Acceptance Rate:                        0.704486
# Replacements:                               1900
# Total Samples:                              2697
# Nested Sampling ln(Z):              26559.287939
# Importance Nested Sampling ln(Z):   27256.323994 +/-  0.891377
# Acceptance Rate:                        0.704734
# Replacements:                               1950
# Total Samples:                              2767
# Nested Sampling ln(Z):              26642.087598
# Importance Nested Sampling ln(Z):   27268.502574 +/-  0.999815
# Acceptance Rate:                        0.697107
# Replacements:                               2000
# Total Samples:                              2869
# Nested Sampling ln(Z):              26713.626589
# Importance Nested Sampling ln(Z):   27268.383176 +/-  0.999821
# Acceptance Rate:                        0.695387
# Replacements:                               2050
# Total Samples:                              2948
# Nested Sampling ln(Z):              26781.216071
# Importance Nested Sampling ln(Z):   27268.284082 +/-  0.999826
# Acceptance Rate:                        0.692384
# Replacements:                               2100
# Total Samples:                              3033
# Nested Sampling ln(Z):              26835.941130
# Importance Nested Sampling ln(Z):   27268.189727 +/-  0.999830
# Acceptance Rate:                        0.686462
# Replacements:                               2150
# Total Samples:                              3132
# Nested Sampling ln(Z):              26888.718454
# Importance Nested Sampling ln(Z):   27268.087845 +/-  0.999835
# Acceptance Rate:                        0.685145
# Replacements:                               2200
# Total Samples:                              3211
# Nested Sampling ln(Z):              26928.323952
# Importance Nested Sampling ln(Z):   27268.010693 +/-  0.999839
# Acceptance Rate:                        0.680787
# Replacements:                               2250
# Total Samples:                              3305
# Nested Sampling ln(Z):              26975.543995
# Importance Nested Sampling ln(Z):   27274.071583 +/-  0.997749
# Acceptance Rate:                        0.678466
# Replacements:                               2300
# Total Samples:                              3390
# Nested Sampling ln(Z):              27008.328022
# Importance Nested Sampling ln(Z):   27273.978273 +/-  0.997753
# Acceptance Rate:                        0.674125
# Replacements:                               2350
# Total Samples:                              3486
# Nested Sampling ln(Z):              27036.490361
# Importance Nested Sampling ln(Z):   27273.885729 +/-  0.997702
# Acceptance Rate:                        0.670578
# Replacements:                               2400
# Total Samples:                              3579
# Nested Sampling ln(Z):              27060.211897
# Importance Nested Sampling ln(Z):   27273.801544 +/-  0.991267
# Acceptance Rate:                        0.669033
# Replacements:                               2450
# Total Samples:                              3662
# Nested Sampling ln(Z):              27083.417556
# Importance Nested Sampling ln(Z):   27273.714112 +/-  0.991269
# Acceptance Rate:                        0.668271
# Replacements:                               2500
# Total Samples:                              3741
# Nested Sampling ln(Z):              27104.130835
# Importance Nested Sampling ln(Z):   27273.634482 +/-  0.991261
# Acceptance Rate:                        0.667365
# Replacements:                               2550
# Total Samples:                              3821
# Nested Sampling ln(Z):              27121.151573
# Importance Nested Sampling ln(Z):   27273.594034 +/-  0.953301
# Acceptance Rate:                        0.666325
# Replacements:                               2600
# Total Samples:                              3902
# Nested Sampling ln(Z):              27137.138093
# Importance Nested Sampling ln(Z):   27273.511989 +/-  0.951202
# Acceptance Rate:                        0.664327
# Replacements:                               2650
# Total Samples:                              3989
# Nested Sampling ln(Z):              27151.341319
# Importance Nested Sampling ln(Z):   27273.427804 +/-  0.951199
# Acceptance Rate:                        0.660793
# Replacements:                               2700
# Total Samples:                              4086
# Nested Sampling ln(Z):              27165.065128
# Importance Nested Sampling ln(Z):   27273.324838 +/-  0.951074
# Acceptance Rate:                        0.657737
# Replacements:                               2750
# Total Samples:                              4181
# Nested Sampling ln(Z):              27175.945680
# Importance Nested Sampling ln(Z):   27273.217500 +/-  0.951066
# Acceptance Rate:                        0.651921
# Replacements:                               2800
# Total Samples:                              4295
# Nested Sampling ln(Z):              27185.496452
# Importance Nested Sampling ln(Z):   27273.099673 +/-  0.951057
# Acceptance Rate:                        0.649499
# Replacements:                               2850
# Total Samples:                              4388
# Nested Sampling ln(Z):              27191.774393
# Importance Nested Sampling ln(Z):   27273.040562 +/-  0.925113
# Acceptance Rate:                        0.644158
# Replacements:                               2900
# Total Samples:                              4502
# Nested Sampling ln(Z):              27197.984216
# Importance Nested Sampling ln(Z):   27272.929744 +/-  0.924868
# Acceptance Rate:                        0.643964
# Replacements:                               2950
# Total Samples:                              4581
# Nested Sampling ln(Z):              27204.377238
# Importance Nested Sampling ln(Z):   27272.878998 +/-  0.891898
# Acceptance Rate:                        0.642949
# Replacements:                               3000
# Total Samples:                              4666
# Nested Sampling ln(Z):              27209.556746
# Importance Nested Sampling ln(Z):   27272.824445 +/-  0.861995
# Acceptance Rate:                        0.640218
# Replacements:                               3050
# Total Samples:                              4764
# Nested Sampling ln(Z):              27214.424469
# Importance Nested Sampling ln(Z):   27272.729177 +/-  0.861792
# Acceptance Rate:                        0.638780
# Replacements:                               3100
# Total Samples:                              4853
# Nested Sampling ln(Z):              27218.592565
# Importance Nested Sampling ln(Z):   27272.636095 +/-  0.861460
# Acceptance Rate:                        0.636107
# Replacements:                               3150
# Total Samples:                              4952
# Nested Sampling ln(Z):              27222.962350
# Importance Nested Sampling ln(Z):   27272.785084 +/-  0.701953
# Acceptance Rate:                        0.634417
# Replacements:                               3200
# Total Samples:                              5044
# Nested Sampling ln(Z):              27226.619989
# Importance Nested Sampling ln(Z):   27272.769340 +/-  0.649172
# Acceptance Rate:                        0.630701
# Replacements:                               3250
# Total Samples:                              5153
# Nested Sampling ln(Z):              27229.724108
# Importance Nested Sampling ln(Z):   27272.687530 +/-  0.633893
# Acceptance Rate:                        0.630132
# Replacements:                               3300
# Total Samples:                              5237
# Nested Sampling ln(Z):              27232.178498
# Importance Nested Sampling ln(Z):   27272.601083 +/-  0.632350
# Acceptance Rate:                        0.626520
# Replacements:                               3350
# Total Samples:                              5347
# Nested Sampling ln(Z):              27234.669580
# Importance Nested Sampling ln(Z):   27272.496825 +/-  0.629614
# Acceptance Rate:                        0.625115
# Replacements:                               3400
# Total Samples:                              5439
# Nested Sampling ln(Z):              27236.495674
# Importance Nested Sampling ln(Z):   27272.483799 +/-  0.575873
# Acceptance Rate:                        0.623306
# Replacements:                               3450
# Total Samples:                              5535
# Nested Sampling ln(Z):              27238.178324
# Importance Nested Sampling ln(Z):   27272.383255 +/-  0.575551
# Acceptance Rate:                        0.618921
# Replacements:                               3500
# Total Samples:                              5655
# Nested Sampling ln(Z):              27239.877963
# Importance Nested Sampling ln(Z):   27272.252261 +/-  0.574749
# Acceptance Rate:                        0.615251
# Replacements:                               3550
# Total Samples:                              5770
# Nested Sampling ln(Z):              27241.498007
# Importance Nested Sampling ln(Z):   27272.148338 +/-  0.565038
# Acceptance Rate:                        0.611933
# Replacements:                               3600
# Total Samples:                              5883
# Nested Sampling ln(Z):              27243.003815
# Importance Nested Sampling ln(Z):   27272.080549 +/-  0.540283
# Acceptance Rate:                        0.609349
# Replacements:                               3650
# Total Samples:                              5990
# Nested Sampling ln(Z):              27244.444220
# Importance Nested Sampling ln(Z):   27272.095993 +/-  0.486737
# Acceptance Rate:                        0.607853
# Replacements:                               3700
# Total Samples:                              6087
# Nested Sampling ln(Z):              27245.592461
# Importance Nested Sampling ln(Z):   27272.010134 +/-  0.484564
# Acceptance Rate:                        0.606600
# Replacements:                               3750
# Total Samples:                              6182
# Nested Sampling ln(Z):              27246.493064
# Importance Nested Sampling ln(Z):   27271.930448 +/-  0.482184
# Acceptance Rate:                        0.603366
# Replacements:                               3800
# Total Samples:                              6298
# Nested Sampling ln(Z):              27247.304602
# Importance Nested Sampling ln(Z):   27271.827164 +/-  0.479417
# Acceptance Rate:                        0.599969
# Replacements:                               3850
# Total Samples:                              6417
# Nested Sampling ln(Z):              27248.105330
# Importance Nested Sampling ln(Z):   27271.738400 +/-  0.467707
# Acceptance Rate:                        0.599447
# Replacements:                               3900
# Total Samples:                              6506
# Nested Sampling ln(Z):              27248.880174
# Importance Nested Sampling ln(Z):   27271.715101 +/-  0.444862
# Acceptance Rate:                        0.598032
# Replacements:                               3950
# Total Samples:                              6605
# Nested Sampling ln(Z):              27249.607478
# Importance Nested Sampling ln(Z):   27271.623138 +/-  0.441136
# Acceptance Rate:                        0.595681
# Replacements:                               4000
# Total Samples:                              6715
# Nested Sampling ln(Z):              27250.274318
# Importance Nested Sampling ln(Z):   27271.577308 +/-  0.417484
# Acceptance Rate:                        0.593146
# Replacements:                               4050
# Total Samples:                              6828
# Nested Sampling ln(Z):              27250.900655
# Importance Nested Sampling ln(Z):   27271.572184 +/-  0.377687
# Acceptance Rate:                        0.590948
# Replacements:                               4100
# Total Samples:                              6938
# Nested Sampling ln(Z):              27251.463429
# Importance Nested Sampling ln(Z):   27271.533070 +/-  0.356389
# Acceptance Rate:                        0.588987
# Replacements:                               4150
# Total Samples:                              7046
# Nested Sampling ln(Z):              27251.969434
# Importance Nested Sampling ln(Z):   27271.445999 +/-  0.353030
# Acceptance Rate:                        0.586428
# Replacements:                               4200
# Total Samples:                              7162
# Nested Sampling ln(Z):              27252.445410
# Importance Nested Sampling ln(Z):   27271.364981 +/-  0.345832
# Acceptance Rate:                        0.582351
# Replacements:                               4250
# Total Samples:                              7298
# Nested Sampling ln(Z):              27252.907001
# Importance Nested Sampling ln(Z):   27271.549288 +/-  0.291780
# Acceptance Rate:                        0.578813
# Replacements:                               4300
# Total Samples:                              7429
# Nested Sampling ln(Z):              27253.334294
# Importance Nested Sampling ln(Z):   27271.695082 +/-  0.264279
# Acceptance Rate:                        0.577919
# Replacements:                               4350
# Total Samples:                              7527
# Nested Sampling ln(Z):              27253.861471
# Importance Nested Sampling ln(Z):   27271.777783 +/-  0.250119
# Acceptance Rate:                        0.576974
# Replacements:                               4400
# Total Samples:                              7626
# Nested Sampling ln(Z):              27254.614116
# Importance Nested Sampling ln(Z):   27271.746525 +/-  0.237836
# Acceptance Rate:                        0.575903
# Replacements:                               4450
# Total Samples:                              7727
# Nested Sampling ln(Z):              27255.493601
# Importance Nested Sampling ln(Z):   27271.701526 +/-  0.229124
# Acceptance Rate:                        0.573833
# Replacements:                               4500
# Total Samples:                              7842
# Nested Sampling ln(Z):              27256.459684
# Importance Nested Sampling ln(Z):   27271.703828 +/-  0.214487
# Acceptance Rate:                        0.571967
# Replacements:                               4550
# Total Samples:                              7955
# Nested Sampling ln(Z):              27257.464762
# Importance Nested Sampling ln(Z):   27271.729337 +/-  0.198318
# Acceptance Rate:                        0.570861
# Replacements:                               4600
# Total Samples:                              8058
# Nested Sampling ln(Z):              27258.420890
# Importance Nested Sampling ln(Z):   27271.778397 +/-  0.189143
# Acceptance Rate:                        0.568947
# Replacements:                               4650
# Total Samples:                              8173
# Nested Sampling ln(Z):              27259.389626
# Importance Nested Sampling ln(Z):   27271.820036 +/-  0.177468
# Acceptance Rate:                        0.564972
# Replacements:                               4700
# Total Samples:                              8319
# Nested Sampling ln(Z):              27260.363733
# Importance Nested Sampling ln(Z):   27271.795924 +/-  0.172500
# Acceptance Rate:                        0.562996
# Replacements:                               4750
# Total Samples:                              8437
# Nested Sampling ln(Z):              27261.245866
# Importance Nested Sampling ln(Z):   27271.823859 +/-  0.159806
# Acceptance Rate:                        0.561864
# Replacements:                               4800
# Total Samples:                              8543
# Nested Sampling ln(Z):              27262.079162
# Importance Nested Sampling ln(Z):   27271.874014 +/-  0.160901
# Acceptance Rate:                        0.559788
# Replacements:                               4850
# Total Samples:                              8664
# Nested Sampling ln(Z):              27262.826948
# Importance Nested Sampling ln(Z):   27271.864723 +/-  0.151658
# Acceptance Rate:                        0.558087
# Replacements:                               4900
# Total Samples:                              8780
# Nested Sampling ln(Z):              27263.499307
# Importance Nested Sampling ln(Z):   27271.987597 +/-  0.157036
# Acceptance Rate:                        0.555119
# Replacements:                               4950
# Total Samples:                              8917
# Nested Sampling ln(Z):              27264.093532
# Importance Nested Sampling ln(Z):   27271.990173 +/-  0.150806
# Acceptance Rate:                        0.553220
# Replacements:                               5000
# Total Samples:                              9038
# Nested Sampling ln(Z):              27264.703086
# Importance Nested Sampling ln(Z):   27272.013885 +/-  0.142621
# Acceptance Rate:                        0.551671
# Replacements:                               5050
# Total Samples:                              9154
# Nested Sampling ln(Z):              27265.250192
# Importance Nested Sampling ln(Z):   27271.987641 +/-  0.140741
# Acceptance Rate:                        0.550221
# Replacements:                               5100
# Total Samples:                              9269
# Nested Sampling ln(Z):              27265.782433
# Importance Nested Sampling ln(Z):   27272.068014 +/-  0.129970
# Acceptance Rate:                        0.548106
# Replacements:                               5150
# Total Samples:                              9396
# Nested Sampling ln(Z):              27266.247929
# Importance Nested Sampling ln(Z):   27272.093349 +/-  0.123440
# Acceptance Rate:                        0.545359
# Replacements:                               5200
# Total Samples:                              9535
# Nested Sampling ln(Z):              27266.675774
# Importance Nested Sampling ln(Z):   27272.065104 +/-  0.122684
# Acceptance Rate:                        0.543253
# Replacements:                               5250
# Total Samples:                              9664
# Nested Sampling ln(Z):              27267.087487
# Importance Nested Sampling ln(Z):   27272.086627 +/-  0.118785
# Acceptance Rate:                        0.540100
# Replacements:                               5300
# Total Samples:                              9813
# Nested Sampling ln(Z):              27267.457075
# Importance Nested Sampling ln(Z):   27272.081596 +/-  0.116849
# Acceptance Rate:                        0.537310
# Replacements:                               5350
# Total Samples:                              9957
# Nested Sampling ln(Z):              27267.789682
# Importance Nested Sampling ln(Z):   27272.086829 +/-  0.114751
# Acceptance Rate:                        0.536033
# Replacements:                               5400
# Total Samples:                             10074
# Nested Sampling ln(Z):              27268.105305
# Importance Nested Sampling ln(Z):   27272.080189 +/-  0.113806
# Acceptance Rate:                        0.534733
# Replacements:                               5450
# Total Samples:                             10192
# Nested Sampling ln(Z):              27268.398792
# Importance Nested Sampling ln(Z):   27272.081316 +/-  0.112107
# Acceptance Rate:                        0.534344
# Replacements:                               5500
# Total Samples:                             10293
# Nested Sampling ln(Z):              27268.674810
# Importance Nested Sampling ln(Z):   27272.118805 +/-  0.107532
# Acceptance Rate:                        0.531762
# Replacements:                               5550
# Total Samples:                             10437
# Nested Sampling ln(Z):              27268.940928
# Importance Nested Sampling ln(Z):   27272.104005 +/-  0.107492
# Acceptance Rate:                        0.529902
# Replacements:                               5600
# Total Samples:                             10568
# Nested Sampling ln(Z):              27269.198201
# Importance Nested Sampling ln(Z):   27272.110387 +/-  0.105734
# Acceptance Rate:                        0.527495
# Replacements:                               5650
# Total Samples:                             10711
# Nested Sampling ln(Z):              27269.439285
# Importance Nested Sampling ln(Z):   27272.144071 +/-  0.102425
# Acceptance Rate:                        0.527046
# Replacements:                               5700
# Total Samples:                             10815
# Nested Sampling ln(Z):              27269.662876
# Importance Nested Sampling ln(Z):   27272.149666 +/-  0.101383
# Acceptance Rate:                        0.525498
# Replacements:                               5750
# Total Samples:                             10942
# Nested Sampling ln(Z):              27269.870340
# Importance Nested Sampling ln(Z):   27272.169400 +/-  0.100045
# Acceptance Rate:                        0.523939
# Replacements:                               5800
# Total Samples:                             11070
# Nested Sampling ln(Z):              27270.065149
# Importance Nested Sampling ln(Z):   27272.172376 +/-  0.098510
# Acceptance Rate:                        0.521762
# Replacements:                               5850
# Total Samples:                             11212
# Nested Sampling ln(Z):              27270.252907
# Importance Nested Sampling ln(Z):   27272.194870 +/-  0.095912
# Acceptance Rate:                        0.519275
# Replacements:                               5900
# Total Samples:                             11362
# Nested Sampling ln(Z):              27270.431888
# Importance Nested Sampling ln(Z):   27272.196156 +/-  0.095055
# Acceptance Rate:                        0.518293
# Replacements:                               5950
# Total Samples:                             11480
# Nested Sampling ln(Z):              27270.598003
# Importance Nested Sampling ln(Z):   27272.199084 +/-  0.094093
# Acceptance Rate:                        0.515907
# Replacements:                               6000
# Total Samples:                             11630
# Nested Sampling ln(Z):              27270.755713
# Importance Nested Sampling ln(Z):   27272.202364 +/-  0.093346
# Acceptance Rate:                        0.514106
# Replacements:                               6050
# Total Samples:                             11768
# Nested Sampling ln(Z):              27270.903303
# Importance Nested Sampling ln(Z):   27272.196989 +/-  0.093091
# Acceptance Rate:                        0.512476
# Replacements:                               6100
# Total Samples:                             11903
# Nested Sampling ln(Z):              27271.040773
# Importance Nested Sampling ln(Z):   27272.201417 +/-  0.092186
# Acceptance Rate:                        0.511307
# Replacements:                               6150
# Total Samples:                             12028
# Nested Sampling ln(Z):              27271.166295
# Importance Nested Sampling ln(Z):   27272.202296 +/-  0.091611
# Acceptance Rate:                        0.511045
# Replacements:                               6200
# Total Samples:                             12132
# Nested Sampling ln(Z):              27271.282730
# Importance Nested Sampling ln(Z):   27272.201732 +/-  0.091254
# Acceptance Rate:                        0.508047
# Replacements:                               6250
# Total Samples:                             12302
# Nested Sampling ln(Z):              27271.392034
# Importance Nested Sampling ln(Z):   27272.188024 +/-  0.091858
# Acceptance Rate:                        0.507614
# Replacements:                               6300
# Total Samples:                             12411
# Nested Sampling ln(Z):              27271.493197
# Importance Nested Sampling ln(Z):   27272.190785 +/-  0.091304
# Acceptance Rate:                        0.504850
# Replacements:                               6350
# Total Samples:                             12578
# Nested Sampling ln(Z):              27271.588982
# Importance Nested Sampling ln(Z):   27272.181625 +/-  0.091668
# Acceptance Rate:                        0.503937
# Replacements:                               6400
# Total Samples:                             12700
# Nested Sampling ln(Z):              27271.677950
# Importance Nested Sampling ln(Z):   27272.185224 +/-  0.091119
# Acceptance Rate:                        0.501166
# Replacements:                               6450
# Total Samples:                             12870
# Nested Sampling ln(Z):              27271.760636
# Importance Nested Sampling ln(Z):   27272.174715 +/-  0.091698
# Acceptance Rate:                        0.500231
# Replacements:                               6500
# Total Samples:                             12994
# Nested Sampling ln(Z):              27271.837752
# Importance Nested Sampling ln(Z):   27272.181194 +/-  0.090944
# Acceptance Rate:                        0.498364
# Replacements:                               6550
# Total Samples:                             13143
# Nested Sampling ln(Z):              27271.910146
# Importance Nested Sampling ln(Z):   27272.182138 +/-  0.090643
# Acceptance Rate:                        0.497213
# Replacements:                               6600
# Total Samples:                             13274
# Nested Sampling ln(Z):              27271.979472
# Importance Nested Sampling ln(Z):   27272.177909 +/-  0.090808
# Acceptance Rate:                        0.495381
# Replacements:                               6650
# Total Samples:                             13424
# Nested Sampling ln(Z):              27272.044121
# Importance Nested Sampling ln(Z):   27272.172353 +/-  0.091120
# Acceptance Rate:                        0.494757
# Replacements:                               6700
# Total Samples:                             13542
# Nested Sampling ln(Z):              27272.103759
# Importance Nested Sampling ln(Z):   27272.171012 +/-  0.091119
# Acceptance Rate:                        0.493061
# Replacements:                               6750
# Total Samples:                             13690
# Nested Sampling ln(Z):              27272.159683
# Importance Nested Sampling ln(Z):   27272.170778 +/-  0.090998
# Acceptance Rate:                        0.491934
# Replacements:                               6800
# Total Samples:                             13823
# Nested Sampling ln(Z):              27272.212505
# Importance Nested Sampling ln(Z):   27272.170749 +/-  0.090898
# Acceptance Rate:                        0.490653
# Replacements:                               6850
# Total Samples:                             13961
# Nested Sampling ln(Z):              27272.261400
# Importance Nested Sampling ln(Z):   27272.171592 +/-  0.090734
# Acceptance Rate:                        0.489570
# Replacements:                               6900
# Total Samples:                             14094
# Nested Sampling ln(Z):              27272.306643
# Importance Nested Sampling ln(Z):   27272.169273 +/-  0.090846
# Acceptance Rate:                        0.487822
# Replacements:                               6950
# Total Samples:                             14247
# Nested Sampling ln(Z):              27272.348678
# Importance Nested Sampling ln(Z):   27272.166863 +/-  0.090972
# Acceptance Rate:                        0.487533
# Replacements:                               7000
# Total Samples:                             14358
# Nested Sampling ln(Z):              27272.387886
# Importance Nested Sampling ln(Z):   27272.170616 +/-  0.090583
# Acceptance Rate:                        0.485738
# Replacements:                               7050
# Total Samples:                             14514
# Nested Sampling ln(Z):              27272.424825
# Importance Nested Sampling ln(Z):   27272.168676 +/-  0.090684
# Acceptance Rate:                        0.484212
# Replacements:                               7100
# Total Samples:                             14663
# Nested Sampling ln(Z):              27272.459364
# Importance Nested Sampling ln(Z):   27272.169268 +/-  0.090581
# Acceptance Rate:                        0.482586
# Replacements:                               7150
# Total Samples:                             14816
# Nested Sampling ln(Z):              27272.491347
# Importance Nested Sampling ln(Z):   27272.166971 +/-  0.090739
# Acceptance Rate:                        0.481123
# Replacements:                               7200
# Total Samples:                             14965
# Nested Sampling ln(Z):              27272.520721
# Importance Nested Sampling ln(Z):   27272.167203 +/-  0.090678
# Acceptance Rate:                        0.479751
# Replacements:                               7250
# Total Samples:                             15112
# Nested Sampling ln(Z):              27272.547903
# Importance Nested Sampling ln(Z):   27272.164683 +/-  0.090869
# Acceptance Rate:                        0.479003
# Replacements:                               7300
# Total Samples:                             15240
# Nested Sampling ln(Z):              27272.573397
# Importance Nested Sampling ln(Z):   27272.165389 +/-  0.090781
# Acceptance Rate:                        0.478080
# Replacements:                               7350
# Total Samples:                             15374
# Nested Sampling ln(Z):              27272.596890
# Importance Nested Sampling ln(Z):   27272.165811 +/-  0.090721
# Acceptance Rate:                        0.476896
# Replacements:                               7400
# Total Samples:                             15517
# Nested Sampling ln(Z):              27272.618714
# Importance Nested Sampling ln(Z):   27272.166559 +/-  0.090634
# Acceptance Rate:                        0.475552
# Replacements:                               7450
# Total Samples:                             15666
# Nested Sampling ln(Z):              27272.638920
# Importance Nested Sampling ln(Z):   27272.165199 +/-  0.090740
# Acceptance Rate:                        0.474143
# Replacements:                               7500
# Total Samples:                             15818
# Nested Sampling ln(Z):              27272.657823
# Importance Nested Sampling ln(Z):   27272.165397 +/-  0.090709
# Acceptance Rate:                        0.472377
# Replacements:                               7550
# Total Samples:                             15983
# Nested Sampling ln(Z):              27272.675445
# Importance Nested Sampling ln(Z):   27272.165159 +/-  0.090719
# Acceptance Rate:                        0.472377
# Replacements:                               7550
# Total Samples:                             15983
# Nested Sampling ln(Z):              27272.675445
# Importance Nested Sampling ln(Z):   27272.165159 +/-  0.090719
#  ln(ev)=   27272.890681533503      +/-  0.14781559463425434
#  Total Likelihood Evaluations:        15983
#  Sampling finished. Exiting MultiNest
#   analysing data from juliet/juliet_oot_exp/jomnest_.txt

# %% [markdown]
# ## Full GP fitting

# %%
# Now we will use posteriors from GP parameters as priors in next full GP fitting
# This will give us the priors on GP parameters
for i in range(len(params_gp)):
    post1 = res_gp_only.posteriors['posterior_samples'][params_gp[i]]
    mu, sig = np.median(post1), np.std(post1)
    dist_gp[i] = 'truncatednormal'
    hyper_gp[i] = [mu, sig, hyper_gp[i][0], hyper_gp[i][1]]

# Doing the same for instrumental parameters
# For sigma_w_CHEOPS
dist_ins[2] = 'truncatednormal'
post2 = res_gp_only.posteriors['posterior_samples']['sigma_w_CHEOPS']
mu, sig = np.median(post2), np.std(post2)
hyper_ins[2] = [mu, sig, hyper_ins[2][0], hyper_ins[2][1]]
# For mflux
dist_ins[1] = 'normal'
post2 = res_gp_only.posteriors['posterior_samples']['mflux_CHEOPS']
mu, sig = np.median(post2), np.std(post2)
hyper_ins[1] = [mu, sig]

# Defining planetary parameters
params_P = ['P_p1', 't0_p1', 'r1_p1', 'r2_p1', 'q1_CHEOPS', 'q2_CHEOPS', 'sesinomega_p1', 'secosomega_p1', 'a_p1']
dist_P = ['fixed', 'normal', 'uniform', 'uniform', 'fixed', 'fixed', 'fixed', 'fixed', 'fixed']
hyper_P = [P, [T_ec, 0.1], [0.,1.], [0.,1.], 0., 0., 0., 0., 4.71779818]

## Making prior dictionary
params = params_P + params_ins + params_gp
dist = dist_P + dist_ins + dist_gp
hyper = hyper_P + hyper_ins + hyper_gp

for i, j, k in zip(params, dist, hyper):
    priors[i] = {}
    priors[i]['distribution'], priors[i]['hyperparameters'] = j, k

# And fitting
data_full = jl.load(priors=priors, t_lc=tim_full, y_lc=fl_full, yerr_lc=fle_full, GP_regressors_lc=tim_full, out_folder='juliet/juliet_full_exp')
results_full = data_full.fit(n_live_points=500, verbose=True)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  500
#  dimensionality =    9
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        1.000000
# Replacements:                                550
# Total Samples:                               550
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29680.641080 +/-  0.661955
# Acceptance Rate:                        0.990099
# Replacements:                                600
# Total Samples:                               606
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29680.544119 +/-  0.662081
# Acceptance Rate:                        0.971599
# Replacements:                                650
# Total Samples:                               669
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29680.445215 +/-  0.662199
# Acceptance Rate:                        0.951087
# Replacements:                                700
# Total Samples:                               736
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z):   29680.349769 +/-  0.662302
# Acceptance Rate:                        0.927070
# Replacements:                                750
# Total Samples:                               809
# Nested Sampling ln(Z):            -864646.955432
# Importance Nested Sampling ln(Z):   29680.466955 +/-  0.567197
# Acceptance Rate:                        0.904977
# Replacements:                                800
# Total Samples:                               884
# Nested Sampling ln(Z):            -555177.717888
# Importance Nested Sampling ln(Z):   29680.379575 +/-  0.566564
# Acceptance Rate:                        0.890985
# Replacements:                                850
# Total Samples:                               954
# Nested Sampling ln(Z):            -351327.848990
# Importance Nested Sampling ln(Z):   29679.467181 +/-  0.566637
# Acceptance Rate:                        0.880626
# Replacements:                                900
# Total Samples:                              1022
# Nested Sampling ln(Z):            -200316.469565
# Importance Nested Sampling ln(Z):   29679.022783 +/-  0.566414
# Acceptance Rate:                        0.863636
# Replacements:                                950
# Total Samples:                              1100
# Nested Sampling ln(Z):            -128339.606964
# Importance Nested Sampling ln(Z):   29678.727425 +/-  0.566475
# Acceptance Rate:                        0.843882
# Replacements:                               1000
# Total Samples:                              1185
# Nested Sampling ln(Z):             -90299.969599
# Importance Nested Sampling ln(Z):   29678.370880 +/-  0.566533
# Acceptance Rate:                        0.834658
# Replacements:                               1050
# Total Samples:                              1258
# Nested Sampling ln(Z):             -54582.725912
# Importance Nested Sampling ln(Z):   29678.134007 +/-  0.566575
# Acceptance Rate:                        0.815419
# Replacements:                               1100
# Total Samples:                              1349
# Nested Sampling ln(Z):             -31451.900148
# Importance Nested Sampling ln(Z):   29678.080069 +/-  0.497510
# Acceptance Rate:                        0.807584
# Replacements:                               1150
# Total Samples:                              1424
# Nested Sampling ln(Z):             -14703.496800
# Importance Nested Sampling ln(Z):   29677.934407 +/-  0.494159
# Acceptance Rate:                        0.799467
# Replacements:                               1200
# Total Samples:                              1501
# Nested Sampling ln(Z):               1114.125599
# Importance Nested Sampling ln(Z):   29677.777443 +/-  0.490336
# Acceptance Rate:                        0.782228
# Replacements:                               1250
# Total Samples:                              1598
# Nested Sampling ln(Z):              10723.712791
# Importance Nested Sampling ln(Z):   29677.804323 +/-  0.439968
# Acceptance Rate:                        0.772889
# Replacements:                               1300
# Total Samples:                              1682
# Nested Sampling ln(Z):              15342.169462
# Importance Nested Sampling ln(Z):   29678.800854 +/-  0.643506
# Acceptance Rate:                        0.764007
# Replacements:                               1350
# Total Samples:                              1767
# Nested Sampling ln(Z):              18607.788578
# Importance Nested Sampling ln(Z):   29678.701646 +/-  0.638883
# Acceptance Rate:                        0.753498
# Replacements:                               1400
# Total Samples:                              1858
# Nested Sampling ln(Z):              21707.632971
# Importance Nested Sampling ln(Z):   29678.587431 +/-  0.633211
# Acceptance Rate:                        0.748194
# Replacements:                               1450
# Total Samples:                              1938
# Nested Sampling ln(Z):              23841.799726
# Importance Nested Sampling ln(Z):   29678.912429 +/-  0.536260
# Acceptance Rate:                        0.736377
# Replacements:                               1500
# Total Samples:                              2037
# Nested Sampling ln(Z):              25287.664839
# Importance Nested Sampling ln(Z):   29678.841355 +/-  0.503911
# Acceptance Rate:                        0.730443
# Replacements:                               1550
# Total Samples:                              2122
# Nested Sampling ln(Z):              26382.084574
# Importance Nested Sampling ln(Z):   29678.784807 +/-  0.480213
# Acceptance Rate:                        0.723327
# Replacements:                               1600
# Total Samples:                              2212
# Nested Sampling ln(Z):              27160.603222
# Importance Nested Sampling ln(Z):   29678.835145 +/-  0.433463
# Acceptance Rate:                        0.716768
# Replacements:                               1650
# Total Samples:                              2302
# Nested Sampling ln(Z):              27817.251373
# Importance Nested Sampling ln(Z):   29678.825820 +/-  0.404908
# Acceptance Rate:                        0.708333
# Replacements:                               1700
# Total Samples:                              2400
# Nested Sampling ln(Z):              28217.919277
# Importance Nested Sampling ln(Z):   29678.737830 +/-  0.394455
# Acceptance Rate:                        0.701403
# Replacements:                               1750
# Total Samples:                              2495
# Nested Sampling ln(Z):              28457.679802
# Importance Nested Sampling ln(Z):   29678.957443 +/-  0.357483
# Acceptance Rate:                        0.696864
# Replacements:                               1800
# Total Samples:                              2583
# Nested Sampling ln(Z):              28714.691272
# Importance Nested Sampling ln(Z):   29678.923525 +/-  0.338786
# Acceptance Rate:                        0.693403
# Replacements:                               1850
# Total Samples:                              2668
# Nested Sampling ln(Z):              28950.230981
# Importance Nested Sampling ln(Z):   29678.851155 +/-  0.332473
# Acceptance Rate:                        0.690658
# Replacements:                               1900
# Total Samples:                              2751
# Nested Sampling ln(Z):              29067.479627
# Importance Nested Sampling ln(Z):   29678.811716 +/-  0.317697
# Acceptance Rate:                        0.687588
# Replacements:                               1950
# Total Samples:                              2836
# Nested Sampling ln(Z):              29194.717547
# Importance Nested Sampling ln(Z):   29679.249631 +/-  0.404275
# Acceptance Rate:                        0.683527
# Replacements:                               2000
# Total Samples:                              2926
# Nested Sampling ln(Z):              29290.989749
# Importance Nested Sampling ln(Z):   29679.421413 +/-  0.343059
# Acceptance Rate:                        0.681289
# Replacements:                               2050
# Total Samples:                              3009
# Nested Sampling ln(Z):              29380.963142
# Importance Nested Sampling ln(Z):   29679.372082 +/-  0.330012
# Acceptance Rate:                        0.678733
# Replacements:                               2100
# Total Samples:                              3094
# Nested Sampling ln(Z):              29435.149849
# Importance Nested Sampling ln(Z):   29679.829194 +/-  0.372584
# Acceptance Rate:                        0.673559
# Replacements:                               2150
# Total Samples:                              3192
# Nested Sampling ln(Z):              29490.074464
# Importance Nested Sampling ln(Z):   29679.755715 +/-  0.362965
# Acceptance Rate:                        0.670119
# Replacements:                               2200
# Total Samples:                              3283
# Nested Sampling ln(Z):              29529.941869
# Importance Nested Sampling ln(Z):   29679.740017 +/-  0.338602
# Acceptance Rate:                        0.663521
# Replacements:                               2250
# Total Samples:                              3391
# Nested Sampling ln(Z):              29557.668645
# Importance Nested Sampling ln(Z):   29679.679312 +/-  0.319563
# Acceptance Rate:                        0.656205
# Replacements:                               2300
# Total Samples:                              3505
# Nested Sampling ln(Z):              29579.020397
# Importance Nested Sampling ln(Z):   29679.731758 +/-  0.283021
# Acceptance Rate:                        0.651150
# Replacements:                               2350
# Total Samples:                              3609
# Nested Sampling ln(Z):              29595.257198
# Importance Nested Sampling ln(Z):   29679.786461 +/-  0.264741
# Acceptance Rate:                        0.647075
# Replacements:                               2400
# Total Samples:                              3709
# Nested Sampling ln(Z):              29608.796609
# Importance Nested Sampling ln(Z):   29679.926391 +/-  0.265768
# Acceptance Rate:                        0.642034
# Replacements:                               2450
# Total Samples:                              3816
# Nested Sampling ln(Z):              29622.217299
# Importance Nested Sampling ln(Z):   29679.926372 +/-  0.240179
# Acceptance Rate:                        0.638081
# Replacements:                               2500
# Total Samples:                              3918
# Nested Sampling ln(Z):              29630.718841
# Importance Nested Sampling ln(Z):   29680.308638 +/-  0.337280
# Acceptance Rate:                        0.636386
# Replacements:                               2550
# Total Samples:                              4007
# Nested Sampling ln(Z):              29638.000686
# Importance Nested Sampling ln(Z):   29680.295249 +/-  0.318791
# Acceptance Rate:                        0.632450
# Replacements:                               2600
# Total Samples:                              4111
# Nested Sampling ln(Z):              29643.861722
# Importance Nested Sampling ln(Z):   29680.284287 +/-  0.303415
# Acceptance Rate:                        0.626626
# Replacements:                               2650
# Total Samples:                              4229
# Nested Sampling ln(Z):              29650.003362
# Importance Nested Sampling ln(Z):   29680.244446 +/-  0.309035
# Acceptance Rate:                        0.622550
# Replacements:                               2700
# Total Samples:                              4337
# Nested Sampling ln(Z):              29654.264053
# Importance Nested Sampling ln(Z):   29680.241758 +/-  0.305920
# Acceptance Rate:                        0.620487
# Replacements:                               2750
# Total Samples:                              4432
# Nested Sampling ln(Z):              29657.946240
# Importance Nested Sampling ln(Z):   29680.350031 +/-  0.283534
# Acceptance Rate:                        0.611888
# Replacements:                               2800
# Total Samples:                              4576
# Nested Sampling ln(Z):              29660.761612
# Importance Nested Sampling ln(Z):   29680.308810 +/-  0.289185
# Acceptance Rate:                        0.610017
# Replacements:                               2850
# Total Samples:                              4672
# Nested Sampling ln(Z):              29663.161473
# Importance Nested Sampling ln(Z):   29680.385881 +/-  0.270262
# Acceptance Rate:                        0.605175
# Replacements:                               2900
# Total Samples:                              4792
# Nested Sampling ln(Z):              29665.747359
# Importance Nested Sampling ln(Z):   29680.380689 +/-  0.267059
# Acceptance Rate:                        0.599715
# Replacements:                               2950
# Total Samples:                              4919
# Nested Sampling ln(Z):              29668.204925
# Importance Nested Sampling ln(Z):   29680.367040 +/-  0.267272
# Acceptance Rate:                        0.596540
# Replacements:                               3000
# Total Samples:                              5029
# Nested Sampling ln(Z):              29670.006878
# Importance Nested Sampling ln(Z):   29680.338102 +/-  0.271839
# Acceptance Rate:                        0.592118
# Replacements:                               3050
# Total Samples:                              5151
# Nested Sampling ln(Z):              29671.396288
# Importance Nested Sampling ln(Z):   29680.338017 +/-  0.269770
# Acceptance Rate:                        0.589242
# Replacements:                               3100
# Total Samples:                              5261
# Nested Sampling ln(Z):              29672.404309
# Importance Nested Sampling ln(Z):   29680.413025 +/-  0.257025
# Acceptance Rate:                        0.585720
# Replacements:                               3150
# Total Samples:                              5378
# Nested Sampling ln(Z):              29673.278931
# Importance Nested Sampling ln(Z):   29680.408968 +/-  0.255307
# Acceptance Rate:                        0.582242
# Replacements:                               3200
# Total Samples:                              5496
# Nested Sampling ln(Z):              29674.073318
# Importance Nested Sampling ln(Z):   29680.534966 +/-  0.247107
# Acceptance Rate:                        0.578601
# Replacements:                               3250
# Total Samples:                              5617
# Nested Sampling ln(Z):              29674.810039
# Importance Nested Sampling ln(Z):   29680.531502 +/-  0.243015
# Acceptance Rate:                        0.576117
# Replacements:                               3300
# Total Samples:                              5728
# Nested Sampling ln(Z):              29675.520774
# Importance Nested Sampling ln(Z):   29680.507872 +/-  0.243676
# Acceptance Rate:                        0.574220
# Replacements:                               3350
# Total Samples:                              5834
# Nested Sampling ln(Z):              29676.159304
# Importance Nested Sampling ln(Z):   29680.653141 +/-  0.243056
# Acceptance Rate:                        0.570470
# Replacements:                               3400
# Total Samples:                              5960
# Nested Sampling ln(Z):              29676.733157
# Importance Nested Sampling ln(Z):   29680.696293 +/-  0.227293
# Acceptance Rate:                        0.567621
# Replacements:                               3450
# Total Samples:                              6078
# Nested Sampling ln(Z):              29677.241785
# Importance Nested Sampling ln(Z):   29680.671019 +/-  0.225931
# Acceptance Rate:                        0.565154
# Replacements:                               3500
# Total Samples:                              6193
# Nested Sampling ln(Z):              29677.713513
# Importance Nested Sampling ln(Z):   29680.651230 +/-  0.224720
# Acceptance Rate:                        0.563224
# Replacements:                               3550
# Total Samples:                              6303
# Nested Sampling ln(Z):              29678.115800
# Importance Nested Sampling ln(Z):   29680.683893 +/-  0.218328
# Acceptance Rate:                        0.559354
# Replacements:                               3600
# Total Samples:                              6436
# Nested Sampling ln(Z):              29678.470618
# Importance Nested Sampling ln(Z):   29680.651006 +/-  0.218806
# Acceptance Rate:                        0.551860
# Replacements:                               3650
# Total Samples:                              6614
# Nested Sampling ln(Z):              29678.776707
# Importance Nested Sampling ln(Z):   29680.631100 +/-  0.217661
# Acceptance Rate:                        0.546933
# Replacements:                               3700
# Total Samples:                              6765
# Nested Sampling ln(Z):              29679.046003
# Importance Nested Sampling ln(Z):   29680.623676 +/-  0.214846
# Acceptance Rate:                        0.543163
# Replacements:                               3750
# Total Samples:                              6904
# Nested Sampling ln(Z):              29679.289246
# Importance Nested Sampling ln(Z):   29680.603594 +/-  0.215493
# Acceptance Rate:                        0.540003
# Replacements:                               3800
# Total Samples:                              7037
# Nested Sampling ln(Z):              29679.509605
# Importance Nested Sampling ln(Z):   29680.601135 +/-  0.213619
# Acceptance Rate:                        0.535466
# Replacements:                               3850
# Total Samples:                              7190
# Nested Sampling ln(Z):              29679.701029
# Importance Nested Sampling ln(Z):   29680.694147 +/-  0.206756
# Acceptance Rate:                        0.530252
# Replacements:                               3900
# Total Samples:                              7355
# Nested Sampling ln(Z):              29679.871085
# Importance Nested Sampling ln(Z):   29680.730303 +/-  0.198823
# Acceptance Rate:                        0.523387
# Replacements:                               3950
# Total Samples:                              7547
# Nested Sampling ln(Z):              29680.023148
# Importance Nested Sampling ln(Z):   29680.712340 +/-  0.197695
# Acceptance Rate:                        0.515198
# Replacements:                               4000
# Total Samples:                              7764
# Nested Sampling ln(Z):              29680.160848
# Importance Nested Sampling ln(Z):   29680.673461 +/-  0.200912
# Acceptance Rate:                        0.507519
# Replacements:                               4050
# Total Samples:                              7980
# Nested Sampling ln(Z):              29680.284699
# Importance Nested Sampling ln(Z):   29680.644329 +/-  0.203641
# Acceptance Rate:                        0.503315
# Replacements:                               4100
# Total Samples:                              8146
# Nested Sampling ln(Z):              29680.396184
# Importance Nested Sampling ln(Z):   29680.671766 +/-  0.198681
# Acceptance Rate:                        0.497483
# Replacements:                               4150
# Total Samples:                              8342
# Nested Sampling ln(Z):              29680.495982
# Importance Nested Sampling ln(Z):   29680.660319 +/-  0.199088
# Acceptance Rate:                        0.489339
# Replacements:                               4200
# Total Samples:                              8583
# Nested Sampling ln(Z):              29680.586739
# Importance Nested Sampling ln(Z):   29680.644909 +/-  0.200232
# Acceptance Rate:                        0.484000
# Replacements:                               4250
# Total Samples:                              8781
# Nested Sampling ln(Z):              29680.669113
# Importance Nested Sampling ln(Z):   29680.627599 +/-  0.201977
# Acceptance Rate:                        0.476085
# Replacements:                               4300
# Total Samples:                              9032
# Nested Sampling ln(Z):              29680.743627
# Importance Nested Sampling ln(Z):   29680.655506 +/-  0.196574
# Acceptance Rate:                        0.468548
# Replacements:                               4350
# Total Samples:                              9284
# Nested Sampling ln(Z):              29680.811038
# Importance Nested Sampling ln(Z):   29680.643645 +/-  0.197682
# Acceptance Rate:                        0.460107
# Replacements:                               4400
# Total Samples:                              9563
# Nested Sampling ln(Z):              29680.872182
# Importance Nested Sampling ln(Z):   29680.650229 +/-  0.195723
# Acceptance Rate:                        0.448996
# Replacements:                               4450
# Total Samples:                              9911
# Nested Sampling ln(Z):              29680.927492
# Importance Nested Sampling ln(Z):   29680.634710 +/-  0.197588
# Acceptance Rate:                        0.442130
# Replacements:                               4500
# Total Samples:                             10178
# Nested Sampling ln(Z):              29680.977791
# Importance Nested Sampling ln(Z):   29680.636946 +/-  0.197062
# Acceptance Rate:                        0.430667
# Replacements:                               4550
# Total Samples:                             10565
# Nested Sampling ln(Z):              29681.023558
# Importance Nested Sampling ln(Z):   29680.617506 +/-  0.199855
# Acceptance Rate:                        0.422833
# Replacements:                               4600
# Total Samples:                             10879
# Nested Sampling ln(Z):              29681.065792
# Importance Nested Sampling ln(Z):   29680.625413 +/-  0.197953
# Acceptance Rate:                        0.411504
# Replacements:                               4650
# Total Samples:                             11300
# Nested Sampling ln(Z):              29681.104619
# Importance Nested Sampling ln(Z):   29680.624576 +/-  0.197666
# Acceptance Rate:                        0.399898
# Replacements:                               4700
# Total Samples:                             11753
# Nested Sampling ln(Z):              29681.140622
# Importance Nested Sampling ln(Z):   29680.614086 +/-  0.199421
# Acceptance Rate:                        0.389153
# Replacements:                               4750
# Total Samples:                             12206
# Nested Sampling ln(Z):              29681.174162
# Importance Nested Sampling ln(Z):   29680.602562 +/-  0.201268
# Acceptance Rate:                        0.380680
# Replacements:                               4800
# Total Samples:                             12609
# Nested Sampling ln(Z):              29681.205726
# Importance Nested Sampling ln(Z):   29680.597977 +/-  0.201889
# Acceptance Rate:                        0.370144
# Replacements:                               4850
# Total Samples:                             13103
# Nested Sampling ln(Z):              29681.235315
# Importance Nested Sampling ln(Z):   29680.609655 +/-  0.199730
# Acceptance Rate:                        0.362641
# Replacements:                               4900
# Total Samples:                             13512
# Nested Sampling ln(Z):              29681.263143
# Importance Nested Sampling ln(Z):   29680.607995 +/-  0.199781
# Acceptance Rate:                        0.354508
# Replacements:                               4950
# Total Samples:                             13963
# Nested Sampling ln(Z):              29681.289928
# Importance Nested Sampling ln(Z):   29680.616136 +/-  0.198197
# Acceptance Rate:                        0.338662
# Replacements:                               5000
# Total Samples:                             14764
# Nested Sampling ln(Z):              29681.316223
# Importance Nested Sampling ln(Z):   29680.596662 +/-  0.201705
# Acceptance Rate:                        0.325387
# Replacements:                               5050
# Total Samples:                             15520
# Nested Sampling ln(Z):              29681.341665
# Importance Nested Sampling ln(Z):   29680.591520 +/-  0.202563
# Acceptance Rate:                        0.313364
# Replacements:                               5100
# Total Samples:                             16275
# Nested Sampling ln(Z):              29681.366661
# Importance Nested Sampling ln(Z):   29680.583910 +/-  0.203941
# Acceptance Rate:                        0.301628
# Replacements:                               5150
# Total Samples:                             17074
# Nested Sampling ln(Z):              29681.391133
# Importance Nested Sampling ln(Z):   29680.588026 +/-  0.203028
# Acceptance Rate:                        0.292250
# Replacements:                               5200
# Total Samples:                             17793
# Nested Sampling ln(Z):              29681.415053
# Importance Nested Sampling ln(Z):   29680.597315 +/-  0.201170
# Acceptance Rate:                        0.280599
# Replacements:                               5250
# Total Samples:                             18710
# Nested Sampling ln(Z):              29681.438500
# Importance Nested Sampling ln(Z):   29680.594862 +/-  0.201579
# Acceptance Rate:                        0.273168
# Replacements:                               5300
# Total Samples:                             19402
# Nested Sampling ln(Z):              29681.461576
# Importance Nested Sampling ln(Z):   29680.602513 +/-  0.200036
# Acceptance Rate:                        0.263872
# Replacements:                               5350
# Total Samples:                             20275
# Nested Sampling ln(Z):              29681.483884
# Importance Nested Sampling ln(Z):   29680.605232 +/-  0.199443
# Acceptance Rate:                        0.255876
# Replacements:                               5400
# Total Samples:                             21104
# Nested Sampling ln(Z):              29681.506132
# Importance Nested Sampling ln(Z):   29680.604741 +/-  0.199499
# Acceptance Rate:                        0.247817
# Replacements:                               5450
# Total Samples:                             21992
# Nested Sampling ln(Z):              29681.528409
# Importance Nested Sampling ln(Z):   29680.607129 +/-  0.199018
# Acceptance Rate:                        0.239058
# Replacements:                               5500
# Total Samples:                             23007
# Nested Sampling ln(Z):              29681.550935
# Importance Nested Sampling ln(Z):   29680.605636 +/-  0.199269
# Acceptance Rate:                        0.230262
# Replacements:                               5550
# Total Samples:                             24103
# Nested Sampling ln(Z):              29681.573564
# Importance Nested Sampling ln(Z):   29680.600930 +/-  0.200173
# Acceptance Rate:                        0.225706
# Replacements:                               5600
# Total Samples:                             24811
# Nested Sampling ln(Z):              29681.596495
# Importance Nested Sampling ln(Z):   29680.604249 +/-  0.199499
# Acceptance Rate:                        0.220187
# Replacements:                               5650
# Total Samples:                             25660
# Nested Sampling ln(Z):              29681.620021
# Importance Nested Sampling ln(Z):   29680.608921 +/-  0.198563
# Acceptance Rate:                        0.214012
# Replacements:                               5700
# Total Samples:                             26634
# Nested Sampling ln(Z):              29681.643675
# Importance Nested Sampling ln(Z):   29680.615929 +/-  0.197179
# Acceptance Rate:                        0.207544
# Replacements:                               5750
# Total Samples:                             27705
# Nested Sampling ln(Z):              29681.667481
# Importance Nested Sampling ln(Z):   29680.617303 +/-  0.196900
# Acceptance Rate:                        0.203802
# Replacements:                               5800
# Total Samples:                             28459
# Nested Sampling ln(Z):              29681.690846
# Importance Nested Sampling ln(Z):   29680.625306 +/-  0.195333
# Acceptance Rate:                        0.200576
# Replacements:                               5850
# Total Samples:                             29166
# Nested Sampling ln(Z):              29681.713978
# Importance Nested Sampling ln(Z):   29680.633944 +/-  0.193651
# Acceptance Rate:                        0.199980
# Replacements:                               5900
# Total Samples:                             29503
# Nested Sampling ln(Z):              29681.736897
# Importance Nested Sampling ln(Z):   29680.641049 +/-  0.192280
# Acceptance Rate:                        0.200175
# Replacements:                               5950
# Total Samples:                             29724
# Nested Sampling ln(Z):              29681.759685
# Importance Nested Sampling ln(Z):   29680.650605 +/-  0.190456
# Acceptance Rate:                        0.200676
# Replacements:                               6000
# Total Samples:                             29899
# Nested Sampling ln(Z):              29681.782833
# Importance Nested Sampling ln(Z):   29680.662649 +/-  0.188180
# Acceptance Rate:                        0.201391
# Replacements:                               6050
# Total Samples:                             30041
# Nested Sampling ln(Z):              29681.805959
# Importance Nested Sampling ln(Z):   29680.676602 +/-  0.185587
# Acceptance Rate:                        0.202000
# Replacements:                               6100
# Total Samples:                             30198
# Nested Sampling ln(Z):              29681.828895
# Importance Nested Sampling ln(Z):   29680.686481 +/-  0.183765
# Acceptance Rate:                        0.202649
# Replacements:                               6150
# Total Samples:                             30348
# Nested Sampling ln(Z):              29681.851552
# Importance Nested Sampling ln(Z):   29680.699498 +/-  0.181396
# Acceptance Rate:                        0.203032
# Replacements:                               6200
# Total Samples:                             30537
# Nested Sampling ln(Z):              29681.873525
# Importance Nested Sampling ln(Z):   29680.715339 +/-  0.178556
# Acceptance Rate:                        0.203484
# Replacements:                               6250
# Total Samples:                             30715
# Nested Sampling ln(Z):              29681.895100
# Importance Nested Sampling ln(Z):   29680.726848 +/-  0.176515
# Acceptance Rate:                        0.204115
# Replacements:                               6300
# Total Samples:                             30865
# Nested Sampling ln(Z):              29681.916269
# Importance Nested Sampling ln(Z):   29680.735880 +/-  0.174926
# Acceptance Rate:                        0.204647
# Replacements:                               6350
# Total Samples:                             31029
# Nested Sampling ln(Z):              29681.936845
# Importance Nested Sampling ln(Z):   29680.744876 +/-  0.173357
# Acceptance Rate:                        0.205082
# Replacements:                               6400
# Total Samples:                             31207
# Nested Sampling ln(Z):              29681.956865
# Importance Nested Sampling ln(Z):   29680.754950 +/-  0.171616
# Acceptance Rate:                        0.205827
# Replacements:                               6450
# Total Samples:                             31337
# Nested Sampling ln(Z):              29681.976148
# Importance Nested Sampling ln(Z):   29680.762719 +/-  0.170285
# Acceptance Rate:                        0.206186
# Replacements:                               6500
# Total Samples:                             31525
# Nested Sampling ln(Z):              29681.994689
# Importance Nested Sampling ln(Z):   29680.774546 +/-  0.168280
# Acceptance Rate:                        0.206905
# Replacements:                               6550
# Total Samples:                             31657
# Nested Sampling ln(Z):              29682.012705
# Importance Nested Sampling ln(Z):   29680.784717 +/-  0.166578
# Acceptance Rate:                        0.207612
# Replacements:                               6600
# Total Samples:                             31790
# Nested Sampling ln(Z):              29682.030344
# Importance Nested Sampling ln(Z):   29680.793653 +/-  0.165094
# Acceptance Rate:                        0.208131
# Replacements:                               6650
# Total Samples:                             31951
# Nested Sampling ln(Z):              29682.047267
# Importance Nested Sampling ln(Z):   29680.803014 +/-  0.163552
# Acceptance Rate:                        0.208788
# Replacements:                               6700
# Total Samples:                             32090
# Nested Sampling ln(Z):              29682.063254
# Importance Nested Sampling ln(Z):   29680.812679 +/-  0.161980
# Acceptance Rate:                        0.209237
# Replacements:                               6750
# Total Samples:                             32260
# Nested Sampling ln(Z):              29682.078453
# Importance Nested Sampling ln(Z):   29680.820348 +/-  0.160737
# Acceptance Rate:                        0.209967
# Replacements:                               6800
# Total Samples:                             32386
# Nested Sampling ln(Z):              29682.092956
# Importance Nested Sampling ln(Z):   29680.829373 +/-  0.159293
# Acceptance Rate:                        0.210594
# Replacements:                               6850
# Total Samples:                             32527
# Nested Sampling ln(Z):              29682.106813
# Importance Nested Sampling ln(Z):   29680.838322 +/-  0.157872
# Acceptance Rate:                        0.210893
# Replacements:                               6900
# Total Samples:                             32718
# Nested Sampling ln(Z):              29682.119963
# Importance Nested Sampling ln(Z):   29680.847964 +/-  0.156353
# Acceptance Rate:                        0.211420
# Replacements:                               6950
# Total Samples:                             32873
# Nested Sampling ln(Z):              29682.132439
# Importance Nested Sampling ln(Z):   29680.856017 +/-  0.155097
# Acceptance Rate:                        0.211922
# Replacements:                               7000
# Total Samples:                             33031
# Nested Sampling ln(Z):              29682.144324
# Importance Nested Sampling ln(Z):   29680.862218 +/-  0.154134
# Acceptance Rate:                        0.212394
# Replacements:                               7050
# Total Samples:                             33193
# Nested Sampling ln(Z):              29682.155636
# Importance Nested Sampling ln(Z):   29680.868830 +/-  0.153116
# Acceptance Rate:                        0.212970
# Replacements:                               7100
# Total Samples:                             33338
# Nested Sampling ln(Z):              29682.166291
# Importance Nested Sampling ln(Z):   29680.873294 +/-  0.152429
# Acceptance Rate:                        0.213258
# Replacements:                               7116
# Total Samples:                             33368
# Nested Sampling ln(Z):              29682.169590
# Importance Nested Sampling ln(Z):   29680.875264 +/-  0.152129
#  ln(ev)=   29682.320364300853      +/-  0.12639446032879612
#   analysing data from juliet/juliet_full_exp/jomnest_.txt Total Likelihood Evaluations:        33368
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# Let's plot the results...

# %%
# juliet best fit model
model = results_full.lc.evaluate('CHEOPS')

# Making a plot
fig = plt.figure(figsize=(16,9))
gs = gd.GridSpec(2,1, height_ratios=[2,1])

# Top panel
ax1 = plt.subplot(gs[0])
ax1.errorbar(tim_full['CHEOPS'], fl_full['CHEOPS'], yerr=fle_full['CHEOPS'], fmt='.', alpha=0.3)
ax1.plot(tim_full['CHEOPS'], model, c='k', zorder=100)
ax1.set_ylabel('Relative Flux')
ax1.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
ax1.xaxis.set_major_formatter(plt.NullFormatter())

# Bottom panel
ax2 = plt.subplot(gs[1])
ax2.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-model)*1e6, yerr=fle_full['CHEOPS']*1e6, fmt='.', alpha=0.3)
ax2.axhline(y=0.0, c='black', ls='--')
ax2.set_ylabel('Residuals (ppm)')
ax2.set_xlabel('Time (BJD)')
ax2.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
# Out:
# (0.5328613058663905, 3.047896259929985)

# %%
# juliet best fit GP el
gp_model = results_full.lc.model['CHEOPS']['GP']

# juliet best fit transit model and its errors
transit_model = results_full.lc.model['CHEOPS']['deterministic']
transit_model_err = results_full.lc.model['CHEOPS']['deterministic_errors']
umodel, lmodel = transit_model + transit_model_err, transit_model - transit_model_err

# Normalising the data and fitting
fac = 1/np.max(transit_model)

# Making a plot
fig = plt.figure(figsize=(16,9))
gs = gd.GridSpec(2,1, height_ratios=[2,1])

# Top panel
ax1 = plt.subplot(gs[0])
ax1.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-gp_model)*fac, yerr=fle_full['CHEOPS'], fmt='.', alpha=0.3)
ax1.plot(tim_full['CHEOPS'], transit_model*fac, c='k', zorder=100)
ax1.fill_between(tim_full['CHEOPS'], umodel*fac, lmodel*fac, color='red', alpha=0.7, zorder=5)
ax1.set_ylabel('Relative Flux')
ax1.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
ax1.xaxis.set_major_formatter(plt.NullFormatter())

# Bottom panel
ax2 = plt.subplot(gs[1])
ax2.errorbar(tim_full['CHEOPS'], (fl_full['CHEOPS']-gp_model-transit_model)*1e6*fac, yerr=fle_full['CHEOPS']*1e6, fmt='.', alpha=0.3)
ax2.axhline(y=0.0, c='black', ls='--')
ax2.set_ylabel('Residuals (ppm)')
ax2.set_xlabel('Time (BJD)')
ax2.set_xlim(np.min(tim_full['CHEOPS']), np.max(tim_full['CHEOPS']))
# Out:
# (0.5328613058663905, 3.047896259929985)

# %% [markdown]
# It seems that the fit was good?! Let's check the evidence in favour of this

# %%
print(results_full.posteriors['lnZ'])
# Out:
# 29680.87526410314
